# %%
# training.ipynb
import pandas as pd
import joblib
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

# 1. 데이터 불러오기
df = pd.read_csv('data.csv')

# 2. 데이터 나누기 (Train 80% / Test 20%)
X_train, X_test, y_train, y_test = train_test_split(
    df['sentence'], df['label'], test_size=0.2, random_state=42, stratify=df['label']
)

# Test 데이터셋 저장 (평가용)
test_df = pd.DataFrame({'sentence': X_test, 'label': y_test})
test_df.to_csv('test_dataset.csv', index=False)

# 3. 모델 파이프라인 만들기
model = make_pipeline(
    TfidfVectorizer(stop_words='english'),
    MultinomialNB()
)

# 4. 학습시키기
model.fit(X_train, y_train)
print("학습 완료!")

# 5. 모델 저장하기
joblib.dump(model, 'model.pkl')
print("저장 완료: model.pkl, test_dataset.csv")
# Out:
# 학습 완료!
# 저장 완료: model.pkl, test_dataset.csv
