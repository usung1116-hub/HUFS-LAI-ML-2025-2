# %% [markdown]
# # MNIST 손글씨 숫자 분류 튜토리얼
#
# 이 노트북에서는 PyTorch를 사용하여 MNIST 데이터셋의 손글씨 숫자를 분류하는 간단한 Multi-Layer Perceptron (MLP) 모델을 구현합니다.
#
# ## 학습 목표
# 1. PyTorch를 이용한 기본적인 신경망 구현
# 2. 데이터 로딩 및 전처리 과정 이해
# 3. 모델 훈련 및 평가 과정 체험
# 4. 예측 결과 시각화 및 분석
#
# ## 데이터셋 정보
# - **MNIST**: 28x28 픽셀의 흑백 손글씨 숫자 이미지 (0-9)
# - **훈련 데이터**: 60,000개
# - **테스트 데이터**: 10,000개

# %% [markdown]
# ## 1. 라이브러리 임포트
#
# 먼저 필요한 라이브러리들을 임포트합니다:
#
# - **torch**: PyTorch의 핵심 라이브러리
# - **torch.nn**: 신경망 레이어와 손실함수
# - **torch.optim**: 최적화 알고리즘 (Adam, SGD 등)
# - **torchvision.transforms**: 이미지 전처리
# - **datasets**: HuggingFace 데이터셋 라이브러리
# - **matplotlib**: 시각화
# - **numpy**: 수치 계산

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
from datasets import load_dataset
import matplotlib.pyplot as plt
import numpy as np

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("Using CPU")
# Out:
# PyTorch version: 2.8.0+cu126
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# ## 2. MLP (Multi-Layer Perceptron) 모델 정의
#
# 간단한 3층 신경망을 구현합니다:
#
# 1. **입력층**: 784개 뉴런 (28×28 픽셀을 1차원으로 펼침)
# 2. **은닉층**: 100개 뉴런 + ReLU 활성화 함수
# 3. **출력층**: 10개 뉴런 (0-9 클래스)
#
# ### 주요 개념:
# - **nn.Linear**: Fully Connected Layer (혹은 Dense Layer)
# - **nn.ReLU**: ReLU 활성화 함수 (음수는 0, 양수는 그대로)
# - **nn.Sequential**: 레이어들을 순차적으로 연결

# %%
class MLP(nn.Module):
    def __init__(self, input_size=784, hidden_size=100, num_classes=10):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, hidden_size),  # 784 -> 100
            nn.ReLU(),                          # 활성화 함수
            nn.Linear(hidden_size, num_classes) # 100 -> 10
        )

    def forward(self, x):
        """
        순전파 함수 // forward propagation
        x: 입력 텐서 (batch_size, 784)
        return: 출력 텐서 (batch_size, 10)
        """
        return self.layers(x)

# 모델 생성 및 구조 확인
model = MLP()
print("모델 구조:")
print(model)

# 파라미터 개수 계산
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\n총 파라미터 수: {total_params:,}")
print(f"학습 가능한 파라미터 수: {trainable_params:,}")

# 각 레이어별 파라미터 수 확인
print("\n레이어별 파라미터:")
for name, param in model.named_parameters():
    print(f"{name}: {param.shape} ({param.numel():,} 개)")
# Out:
# 모델 구조:
# MLP(
#   (layers): Sequential(
#     (0): Linear(in_features=784, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
#
# 총 파라미터 수: 79,510
# 학습 가능한 파라미터 수: 79,510
#
# 레이어별 파라미터:
# layers.0.weight: torch.Size([100, 784]) (78,400 개)
# layers.0.bias: torch.Size([100]) (100 개)
# layers.2.weight: torch.Size([10, 100]) (1,000 개)
# layers.2.bias: torch.Size([10]) (10 개)

# %% [markdown]
# ## 3. 데이터 로딩 및 전처리
#
# ### 3.1 하이퍼파라미터 설정
#
# 먼저 학습에 사용할 하이퍼파라미터들을 정의합니다:
#
# - **batch_size**: 한 번에 처리할 데이터의 개수
# - **learning_rate**: 학습률 (너무 크면 발산, 너무 작으면 학습이 느림)
# - **epochs**: 전체 데이터셋을 몇 번 반복할지

# %%
# 하이퍼파라미터 설정
batch_size = 128        # 배치 크기
test_batch_size = 1000  # 테스트 배치 크기 (메모리 효율을 위해 크게 설정)
learning_rate = 1e-3    # 학습률 (0.001)
nb_epochs = 3           # 에포크 수

print("=== 하이퍼파라미터 ===")
print(f"배치 크기: {batch_size}")
print(f"테스트 배치 크기: {test_batch_size}")
print(f"학습률: {learning_rate}")
print(f"에포크 수: {nb_epochs}")

# 디바이스 설정 (GPU가 있으면 GPU 사용)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\n사용 디바이스: {device}")
if device.type == "cuda":
    print(f"GPU 이름: {torch.cuda.get_device_name(0)}")
    print(f"GPU 메모리: {torch.cuda.get_device_properties(0).total_memory // 1024**3} GB")
# Out:
# === 하이퍼파라미터 ===
# 배치 크기: 128
# 테스트 배치 크기: 1000
# 학습률: 0.001
# 에포크 수: 3
#
# 사용 디바이스: cuda
# GPU 이름: Tesla T4
# GPU 메모리: 14 GB

# %% [markdown]
# ### 3.2 MNIST 데이터셋 로딩
#
# HuggingFace datasets 라이브러리를 사용하여 MNIST 데이터를 로드합니다.

# %%
# MNIST 데이터셋 로딩
print("MNIST 데이터셋을 다운로드 중...")
mnist = load_dataset("mnist")

# 데이터셋 정보 출력
print("\n=== 데이터셋 정보 ===")
print(f"훈련 데이터: {len(mnist['train']):,}개")
print(f"테스트 데이터: {len(mnist['test']):,}개")
print(f"클래스 수: {len(set(mnist['train']['label']))}개 (0-9)")
print(f"이미지 크기: {mnist['train'][0]['image'].size}")

# 샘플 이미지 확인
sample_image = mnist['train'][0]['image']
sample_label = mnist['train'][0]['label']
print(f"\n첫 번째 샘플: 라벨 {sample_label}")

# 클래스별 개수 확인
from collections import Counter
label_counts = Counter(mnist['train']['label'])
print("\n클래스별 데이터 개수:")
for i in range(10):
    print(f"숫자 {i}: {label_counts[i]:,}개")
# Out:
# MNIST 데이터셋을 다운로드 중...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# mnist/train-00000-of-00001.parquet:   0%|          | 0.00/15.6M [00:00<?, ?B/s]
# mnist/test-00000-of-00001.parquet:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# === 데이터셋 정보 ===
# 훈련 데이터: 60,000개
# 테스트 데이터: 10,000개
# 클래스 수: 10개 (0-9)
# 이미지 크기: (28, 28)
#
# 첫 번째 샘플: 라벨 5
#
# 클래스별 데이터 개수:
# 숫자 0: 5,923개
# 숫자 1: 6,742개
# 숫자 2: 5,958개
# 숫자 3: 6,131개
# 숫자 4: 5,842개
# 숫자 5: 5,421개
# 숫자 6: 5,918개
# 숫자 7: 6,265개
# 숫자 8: 5,851개
# 숫자 9: 5,949개

# %% [markdown]
# ### 3.3 샘플 데이터 시각화
#
# 학습하기 전에 데이터가 어떻게 생겼는지 확인해보겠습니다.

# %%
# 샘플 이미지들 시각화
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
axes = axes.flatten()

for i in range(10):
    # 각 숫자(0-9)에 대해 첫 번째 샘플 찾기
    for j, label in enumerate(mnist['train']['label']):
        if label == i:
            image = mnist['train'][j]['image']
            axes[i].imshow(image, cmap='gray')
            axes[i].set_title(f'Digit {i}')
            axes[i].axis('off')
            break

plt.tight_layout()
plt.suptitle('MNIST Dataset Samples (First image of each digit)', y=1.02)
plt.show()

# %% [markdown]
# ### 3.4 데이터 정규화 (Normalization)
#
# 신경망의 학습을 안정화하기 위해 픽셀 값을 정규화합니다:
# 1. 픽셀 값을 0-1 범위로 변환 (ToTensor())
# 2. 평균과 표준편차를 이용해 정규화 (Normalize())
#
# 정규화 공식: `(픽셀값 - 평균) / 표준편차`

# %%
# 데이터셋의 평균과 표준편차 계산 (1000개 샘플로 추정)
print("데이터셋의 통계 정보를 계산 중...")
sample_data = torch.stack([
    transforms.ToTensor()(mnist['train'][i]['image'])
    for i in range(1000)
])

mean = sample_data.mean().item()
std = sample_data.std().item()
print(f"평균(mean): {mean:.4f}")
print(f"표준편차(std): {std:.4f}")

# Transform 정의
transform = transforms.Compose([
    transforms.ToTensor(),           # PIL Image -> Tensor, 0-255 -> 0-1
    transforms.Normalize((mean,), (std,))  # 정규화
])

print("\n변환 파이프라인:")
print("1. ToTensor(): PIL Image -> PyTorch Tensor (0-255 -> 0-1)")
print(f"2. Normalize(): (픽셀값 - {mean:.4f}) / {std:.4f}")

# 변환 전후 비교
original_pixel = mnist['train'][0]['image']
transformed = transform(original_pixel)
print(f"\n변환 예시:")
print(f"원본 픽셀 범위: 0-255")
print(f"ToTensor 후: 0-1")
print(f"정규화 후 범위: 약 {transformed.min():.2f} ~ {transformed.max():.2f}")
# Out:
# 데이터셋의 통계 정보를 계산 중...
# 평균(mean): 0.1282
# 표준편차(std): 0.3051
#
# 변환 파이프라인:
# 1. ToTensor(): PIL Image -> PyTorch Tensor (0-255 -> 0-1)
# 2. Normalize(): (픽셀값 - 0.1282) / 0.3051
#
# 변환 예시:
# 원본 픽셀 범위: 0-255
# ToTensor 후: 0-1
# 정규화 후 범위: 약 -0.42 ~ 2.86

# %% [markdown]
# ### 3.5 DataLoader 생성
#
# DataLoader는 데이터를 배치 단위로 불러오고, 셔플링 등의 기능을 제공합니다.

# %%
# 데이터 변환 함수 정의
def transform_dataset(dataset):
    """데이터셋에 변환을 적용하는 함수"""
    def transform_fn(batch):
        # 이미지를 텐서로 변환하고 28x28을 784로 평탄화
        images = [transform(img).view(-1) for img in batch["image"]]
        return {
            "image": torch.stack(images),
            "label": torch.tensor(batch["label"])
        }
    return dataset.with_transform(transform_fn)

# 훈련/테스트 데이터셋에 변환 적용
print("데이터셋 변환 중...")
train_dataset = transform_dataset(mnist["train"])
test_dataset = transform_dataset(mnist["test"])

# DataLoader 생성
train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True  # 훈련 데이터는 섞기
)
test_loader = DataLoader(
    test_dataset,
    batch_size=test_batch_size,
    shuffle=False  # 테스트 데이터는 순서 유지
)

print(f"훈련 DataLoader: {len(train_loader)}개 배치")
print(f"테스트 DataLoader: {len(test_loader)}개 배치")
print(f"배치당 훈련 샘플: {batch_size}개")
print(f"배치당 테스트 샘플: {test_batch_size}개")

# 첫 번째 배치 확인
sample_batch = next(iter(train_loader))
print(f"\n첫 번째 배치 shape:")
print(f"이미지: {sample_batch['image'].shape}  # (batch_size, 784)")
print(f"라벨: {sample_batch['label'].shape}    # (batch_size,)")
# Out:
# 데이터셋 변환 중...
# 훈련 DataLoader: 469개 배치
# 테스트 DataLoader: 10개 배치
# 배치당 훈련 샘플: 128개
# 배치당 테스트 샘플: 1000개
#
# 첫 번째 배치 shape:
# 이미지: torch.Size([128, 784])  # (batch_size, 784)
# 라벨: torch.Size([128])    # (batch_size,)

# %% [markdown]
# ## 4. 모델 훈련
#
# ### 4.1 모델, 손실함수, 최적화기 설정

# %%
# 모델 초기화 (이전에 생성한 model 재사용하지 않고 새로 생성)
model = MLP().to(device)  # 모델을 GPU로 이동 (있다면)

# 손실함수: 다중 클래스 분류를 위한 CrossEntropyLoss
criterion = nn.CrossEntropyLoss()

# 최적화기: Adam (적응적 학습률 알고리즘)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

print("=== 훈련 설정 ===")
print(f"모델: {model.__class__.__name__}")
print(f"손실함수: {criterion.__class__.__name__}")
print(f"최적화기: {optimizer.__class__.__name__}")
print(f"디바이스: {device}")
print(f"모델 파라미터 수: {sum(p.numel() for p in model.parameters()):,}개")

# 훈련 설정 요약
print(f"\n=== 훈련 정보 ===")
print(f"전체 에포크: {nb_epochs}")
print(f"배치 크기: {batch_size}")
print(f"학습률: {learning_rate}")
print(f"에포크당 배치 수: {len(train_loader)}")
print(f"에포크당 훈련 샘플 수: {len(train_loader) * batch_size:,}")
print(f"전체 훈련 스텝: {nb_epochs * len(train_loader):,}")
# Out:
# === 훈련 설정 ===
# 모델: MLP
# 손실함수: CrossEntropyLoss
# 최적화기: Adam
# 디바이스: cuda
# 모델 파라미터 수: 79,510개
#
# === 훈련 정보 ===
# 전체 에포크: 3
# 배치 크기: 128
# 학습률: 0.001
# 에포크당 배치 수: 469
# 에포크당 훈련 샘플 수: 60,032
# 전체 훈련 스텝: 1,407

# %% [markdown]
# ### 4.2 훈련 루프 실행
#
# 신경망 훈련의 기본 단계:
# 1. **Forward Pass**: 입력 데이터를 모델에 통과시켜 예측값 계산
# 2. **Loss 계산**: 예측값과 실제값의 차이(오차) 계산
# 3. **Backward Pass**: 역전파를 통해 각 파라미터의 그래디언트 계산
# 4. **Parameter Update**: 최적화기를 사용해 파라미터 업데이트

# %%
# 훈련 과정 추적을 위한 리스트
train_losses = []
train_accuracies = []
test_accuracies = []

print("=== 훈련 시작 ===\n")

for epoch in range(nb_epochs):
    # 훈련 모드로 설정
    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for batch_idx, batch in enumerate(train_loader):
        # 데이터를 디바이스로 이동
        imgs = batch["image"].to(device)
        labels = batch["label"].to(device)

        # 그래디언트 초기화
        optimizer.zero_grad()

        # Forward pass
        outputs = model(imgs)
        loss = criterion(outputs, labels)

        # Backward pass
        loss.backward()

        # 파라미터 업데이트
        optimizer.step()

        # 통계 업데이트
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        # 100 배치마다 중간 결과 출력
        if (batch_idx + 1) % 100 == 0:
            current_loss = running_loss / (batch_idx + 1)
            current_acc = 100 * correct_train / total_train
            print(f"Epoch [{epoch+1}/{nb_epochs}], Batch [{batch_idx+1}/{len(train_loader)}]")
            print(f"  Loss: {current_loss:.4f}, Train Acc: {current_acc:.2f}%")

    # 에포크 종료 후 훈련 통계
    epoch_loss = running_loss / len(train_loader)
    epoch_train_acc = 100 * correct_train / total_train
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_train_acc)

    print(f"\nEpoch [{epoch+1}/{nb_epochs}] 훈련 완료:")
    print(f"  평균 Loss: {epoch_loss:.4f}")
    print(f"  훈련 정확도: {epoch_train_acc:.2f}%")

    # 테스트 정확도 계산
    model.eval()  # 평가 모드로 설정
    correct_test = 0
    total_test = 0

    with torch.no_grad():  # 그래디언트 계산 비활성화
        for batch in test_loader:
            imgs = batch["image"].to(device)
            labels = batch["label"].to(device)

            outputs = model(imgs)
            _, predicted = torch.max(outputs, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

    test_acc = 100 * correct_test / total_test
    test_accuracies.append(test_acc)
    print(f"  테스트 정확도: {test_acc:.2f}%")
    print("-" * 60)

print(f"\n=== 훈련 완료 ===")
print(f"최종 훈련 정확도: {train_accuracies[-1]:.2f}%")
print(f"최종 테스트 정확도: {test_accuracies[-1]:.2f}%")
# Out:
# === 훈련 시작 ===
#
# Epoch [1/3], Batch [100/469]
#   Loss: 0.5993, Train Acc: 83.48%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4416, Train Acc: 87.62%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.3756, Train Acc: 89.35%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3365, Train Acc: 90.41%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3160
#   훈련 정확도: 91.00%
#   테스트 정확도: 94.55%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1484, Train Acc: 95.64%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1460, Train Acc: 95.72%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1441, Train Acc: 95.80%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1402, Train Acc: 95.92%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1401
#   훈련 정확도: 95.95%
#   테스트 정확도: 96.54%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.0984, Train Acc: 97.25%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.0984, Train Acc: 97.12%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.0997, Train Acc: 97.07%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.0988, Train Acc: 97.09%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.0982
#   훈련 정확도: 97.11%
#   테스트 정확도: 97.08%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 97.11%
# 최종 테스트 정확도: 97.08%

# %% [markdown]
# ## 5. 결과 분석 및 시각화
#
# ### 5.1 훈련 과정 시각화
#
# Loss와 정확도의 변화를 그래프로 확인해보겠습니다.

# %%
# 훈련 과정 시각화
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Loss 그래프
epochs_range = range(1, nb_epochs + 1)
ax1.plot(epochs_range, train_losses, 'b-', marker='o', linewidth=2, markersize=8)
ax1.set_title('Training Loss', fontsize=14, fontweight='bold')
ax1.set_xlabel('Epoch', fontsize=12)
ax1.set_ylabel('Loss', fontsize=12)
ax1.grid(True, alpha=0.3)
ax1.set_xticks(epochs_range)

# 정확도 그래프
ax2.plot(epochs_range, train_accuracies, 'g-', marker='s', linewidth=2,
         markersize=8, label='Train Accuracy')
ax2.plot(epochs_range, test_accuracies, 'r-', marker='^', linewidth=2,
         markersize=8, label='Test Accuracy')
ax2.set_title('Accuracy Comparison', fontsize=14, fontweight='bold')
ax2.set_xlabel('Epoch', fontsize=12)
ax2.set_ylabel('Accuracy (%)', fontsize=12)
ax2.grid(True, alpha=0.3)
ax2.legend(fontsize=11)
ax2.set_xticks(epochs_range)
ax2.set_ylim(80, 100)

plt.tight_layout()
plt.show()

# 최종 결과 요약
print("=== 최종 결과 요약 ===")
print(f"최종 훈련 Loss: {train_losses[-1]:.4f}")
print(f"최종 훈련 정확도: {train_accuracies[-1]:.2f}%")
print(f"최종 테스트 정확도: {test_accuracies[-1]:.2f}%")
print(f"과적합 정도: {train_accuracies[-1] - test_accuracies[-1]:.2f}% (훈련-테스트 정확도 차이)")
# Out:
# === 최종 결과 요약 ===
# 최종 훈련 Loss: 0.0982
# 최종 훈련 정확도: 97.11%
# 최종 테스트 정확도: 97.08%
# 과적합 정도: 0.03% (훈련-테스트 정확도 차이)

# %% [markdown]
# ### 5.2 예측 결과 시각화
#
# 모델이 실제로 어떻게 예측하는지 샘플 이미지들을 확인해보겠습니다. 올바른 예측과 틀린 예측을 모두 살펴보겠습니다.

# %%
# 예측 샘플 수집
model.eval()
correct_samples = []
wrong_samples = []

with torch.no_grad():
    for batch in test_loader:
        imgs = batch["image"].to(device)
        labels = batch["label"].to(device)
        outputs = model(imgs)
        _, predicted = torch.max(outputs, 1)

        # 정확한 예측과 틀린 예측 분리
        for i in range(len(imgs)):
            if len(correct_samples) >= 7 and len(wrong_samples) >= 3:
                break

            sample = (imgs[i], labels[i], predicted[i], outputs[i])
            if labels[i] == predicted[i] and len(correct_samples) < 7:
                correct_samples.append(sample)
            elif labels[i] != predicted[i] and len(wrong_samples) < 3:
                wrong_samples.append(sample)

        if len(correct_samples) >= 7 and len(wrong_samples) >= 3:
            break

# 시각화: 7개 맞춘 것 + 3개 틀린 것
display_samples = correct_samples + wrong_samples

fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.flatten()

for i, (img, true_label, pred_label, output) in enumerate(display_samples):
    # 28x28로 reshape (정규화된 상태)
    img_display = img.cpu().view(28, 28)

    # 정규화를 역변환 (시각화를 위해)
    img_display = img_display * std + mean
    img_display = torch.clamp(img_display, 0, 1)

    axes[i].imshow(img_display, cmap='gray')

    # 색상 설정: 맞으면 초록, 틀리면 빨강
    color = 'green' if true_label == pred_label else 'red'
    axes[i].set_title(f'True: {true_label.item()}, Pred: {pred_label.item()}', color=color, fontweight='bold')
    axes[i].axis('off')

plt.tight_layout()
plt.suptitle('Prediction Results (Green: Correct, Red: Wrong)', y=1.02, fontsize=16, fontweight='bold')
plt.show()

print(f"올바른 예측: {len([s for s in display_samples if s[1] == s[2]])}개")
print(f"틀린 예측: {len([s for s in display_samples if s[1] != s[2]])}개")
# Out:
# 올바른 예측: 7개
# 틀린 예측: 3개

# %% [markdown]
# ### 5.3 모델의 확신도 분석
#
# 틀리게 예측한 경우, 모델이 각 클래스에 대해 얼마나 확신했는지 확인해보겠습니다.

# %%
# 틀린 예측에 대한 상세 분석
if wrong_samples:
    wrong_img, wrong_true, wrong_pred, wrong_output = wrong_samples[0]

    # 소프트맥스를 통해 확률로 변환
    probabilities = torch.softmax(wrong_output, dim=0).cpu()

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    # 왼쪽: 틀린 예측 이미지
    img_display = wrong_img.cpu().view(28, 28) * std + mean
    img_display = torch.clamp(img_display, 0, 1)
    ax1.imshow(img_display, cmap='gray')
    ax1.set_title(f'Wrong Prediction Case\\nTrue: {wrong_true.item()}, Pred: {wrong_pred.item()}',
                  color='red', fontsize=12, fontweight='bold')
    ax1.axis('off')

    # 오른쪽: 확률 분포
    bars = ax2.bar(range(10), probabilities, alpha=0.7, color='lightblue', edgecolor='black')

    # 실제 라벨과 예측 라벨 강조
    bars[wrong_true.item()].set_color('green')
    bars[wrong_pred.item()].set_color('red')

    ax2.set_xlabel('Digit Class', fontsize=11)
    ax2.set_ylabel('Probability', fontsize=11)
    ax2.set_title('Model Confidence by Class', fontsize=12, fontweight='bold')
    ax2.set_xticks(range(10))
    ax2.grid(axis='y', alpha=0.3)

    # 범례 추가
    from matplotlib.lines import Line2D
    legend_elements = [Line2D([0], [0], color='green', lw=4, label=f'True Label ({wrong_true.item()})'),
                       Line2D([0], [0], color='red', lw=4, label=f'Predicted ({wrong_pred.item()})')]
    ax2.legend(handles=legend_elements, loc='upper right')

    plt.tight_layout()
    plt.show()

    # 상위 3개 확률 출력
    top3_probs, top3_indices = torch.topk(probabilities, 3)
    print("\\n=== 모델의 상위 3개 예측 ===")
    for i, (prob, idx) in enumerate(zip(top3_probs, top3_indices)):
        print(f"{i+1}위: 숫자 {idx.item()} (확률: {prob.item()*100:.2f}%)")

    print(f"\\n실제 라벨 {wrong_true.item()}의 확률: {probabilities[wrong_true.item()]*100:.2f}%")

else:
    print("틀린 예측 샘플이 없습니다. 모델이 모든 테스트 샘플을 정확히 예측했습니다!")
# Out:
# \n=== 모델의 상위 3개 예측 ===
# 1위: 숫자 6 (확률: 80.71%)
# 2위: 숫자 5 (확률: 17.80%)
# 3위: 숫자 8 (확률: 0.61%)
# \n실제 라벨 5의 확률: 17.80%

# %% [markdown]
# ## 6. 과제 및 실험
#
# ### 💡 학습을 위한 실험 제안
#
# 이제 기본 모델을 이해했으니, 다음과 같은 실험들을 해보세요:
#
# #### 🔧 **Try 1: 하이퍼파라미터 튜닝**
# - 학습률을 바꿔보세요 (`learning_rate = 1e-2`, `1e-4` 등)
# - 은닉층 크기를 조정해보세요 (`hidden_size = 50`, `200` 등)
# - 에포크 수를 늘려보세요 (`nb_epochs = 5` 또는 `10`)
#
# #### 🏗️ **Try 2: 모델 구조 개선**
# - 은닉층을 더 추가해보세요 (3층, 4층 신경망)
# - 다른 활성화 함수를 시도해보세요 (`nn.Tanh()`, `nn.Sigmoid()`)
# - Dropout을 추가해서 과적합을 방지해보세요
#
# #### 📈 **Try 3: 성능 분석**
# - Confusion Matrix 그리기
# - 클래스별 정확도 분석
# - 잘못 분류된 이미지들의 패턴 찾기
#
# ### 📝 **실험 결과 기록하기**
# 각 실험 후 다음을 기록해보세요:
# - 최종 테스트 정확도
# - 훈련 시간
# - 관찰된 패턴이나 인사이트

# %%
# 실험을 위한 빈 셀
# 여기서 위에서 제안한 실험들을 진행해보세요!

# 예시: 학습률을 바꿔서 재훈련
# learning_rate = 1e-2  # 원래보다 10배 큰 학습률
# model = MLP().to(device)
# optimizer = optim.Adam(model.parameters(), lr=learning_rate)
#
# 위의 훈련 루프를 다시 실행하고 결과를 비교해보세요!

print("실험을 시작해보세요! 💪")
# Out:
# 실험을 시작해보세요! 💪

# %%
# 기본 모델 (비교군, 에포크 수만 5으로 증가, 모델의 파라미터 수를 늘려서 진행하는 도중 과적합이 잘 관찰되지 않아 에포크 수를 늘리게 되었습니다. GPT도움)

class MLP(nn.Module):
    def __init__(self, input_size=784, hidden_size=100, num_classes=10):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, hidden_size),  # 784 -> 100
            nn.ReLU(),                          # 활성화 함수
            nn.Linear(hidden_size, num_classes) # 100 -> 10
        )

    def forward(self, x):
        """
        순전파 함수 // forward propagation
        x: 입력 텐서 (batch_size, 784)
        return: 출력 텐서 (batch_size, 10)
        """
        return self.layers(x)

# 모델 초기화 (이전에 생성한 model 재사용하지 않고 새로 생성)
model = MLP().to(device)  # 모델을 GPU로 이동 (있다면)

# 손실함수: 다중 클래스 분류를 위한 CrossEntropyLoss
criterion = nn.CrossEntropyLoss()

# 최적화기: Adam (적응적 학습률 알고리즘)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)


# 하이퍼파라미터 설정
batch_size = 128        # 배치 크기
test_batch_size = 1000  # 테스트 배치 크기 (메모리 효율을 위해 크게 설정)
learning_rate = 1e-3    # 학습률
nb_epochs = 5           # 에포크 수

print("=== 훈련 설정 ===")
print(f"모델: {model.__class__.__name__}")
print(f"손실함수: {criterion.__class__.__name__}")
print(f"최적화기: {optimizer.__class__.__name__}")
print(f"디바이스: {device}")
print(f"모델 파라미터 수: {sum(p.numel() for p in model.parameters()):,}개")

# 훈련 설정 요약
print(f"\n=== 훈련 정보 ===")
print(f"전체 에포크: {nb_epochs}")
print(f"배치 크기: {batch_size}")
print(f"학습률: {learning_rate}")
print(f"에포크당 배치 수: {len(train_loader)}")
print(f"에포크당 훈련 샘플 수: {len(train_loader) * batch_size:,}")
print(f"전체 훈련 스텝: {nb_epochs * len(train_loader):,}")
# Out:
# === 훈련 설정 ===
# 모델: MLP
# 손실함수: CrossEntropyLoss
# 최적화기: Adam
# 디바이스: cuda
# 모델 파라미터 수: 79,510개
#
# === 훈련 정보 ===
# 전체 에포크: 5
# 배치 크기: 128
# 학습률: 0.001
# 에포크당 배치 수: 469
# 에포크당 훈련 샘플 수: 60,032
# 전체 훈련 스텝: 2,345

# %%
# 훈련 과정 추적을 위한 리스트
train_losses = []
train_accuracies = []
test_accuracies = []

print("=== 훈련 시작 ===\n")

for epoch in range(nb_epochs):
    # 훈련 모드로 설정
    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for batch_idx, batch in enumerate(train_loader):
        # 데이터를 디바이스로 이동
        imgs = batch["image"].to(device)
        labels = batch["label"].to(device)

        # 그래디언트 초기화
        optimizer.zero_grad()

        # Forward pass
        outputs = model(imgs)
        loss = criterion(outputs, labels)

        # Backward pass
        loss.backward()

        # 파라미터 업데이트
        optimizer.step()

        # 통계 업데이트
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        # 100 배치마다 중간 결과 출력
        if (batch_idx + 1) % 100 == 0:
            current_loss = running_loss / (batch_idx + 1)
            current_acc = 100 * correct_train / total_train
            print(f"Epoch [{epoch+1}/{nb_epochs}], Batch [{batch_idx+1}/{len(train_loader)}]")
            print(f"  Loss: {current_loss:.4f}, Train Acc: {current_acc:.2f}%")

    # 에포크 종료 후 훈련 통계
    epoch_loss = running_loss / len(train_loader)
    epoch_train_acc = 100 * correct_train / total_train
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_train_acc)

    print(f"\nEpoch [{epoch+1}/{nb_epochs}] 훈련 완료:")
    print(f"  평균 Loss: {epoch_loss:.4f}")
    print(f"  훈련 정확도: {epoch_train_acc:.2f}%")

    # 테스트 정확도 계산
    model.eval()  # 평가 모드로 설정
    correct_test = 0
    total_test = 0

    with torch.no_grad():  # 그래디언트 계산 비활성화
        for batch in test_loader:
            imgs = batch["image"].to(device)
            labels = batch["label"].to(device)

            outputs = model(imgs)
            _, predicted = torch.max(outputs, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

    test_acc = 100 * correct_test / total_test
    test_accuracies.append(test_acc)
    print(f"  테스트 정확도: {test_acc:.2f}%")
    print("-" * 60)

print(f"\n=== 훈련 완료 ===")
print(f"최종 훈련 정확도: {train_accuracies[-1]:.2f}%")
print(f"최종 테스트 정확도: {test_accuracies[-1]:.2f}%")
# Out:
# === 훈련 시작 ===
#
# Epoch [1/5], Batch [100/469]
#   Loss: 0.6027, Train Acc: 83.04%
# Epoch [1/5], Batch [200/469]
#   Loss: 0.4516, Train Acc: 87.03%
# Epoch [1/5], Batch [300/469]
#   Loss: 0.3856, Train Acc: 88.88%
# Epoch [1/5], Batch [400/469]
#   Loss: 0.3436, Train Acc: 90.09%
#
# Epoch [1/5] 훈련 완료:
#   평균 Loss: 0.3232
#   훈련 정확도: 90.69%
#   테스트 정확도: 94.48%
# ------------------------------------------------------------
# Epoch [2/5], Batch [100/469]
#   Loss: 0.1759, Train Acc: 95.10%
# Epoch [2/5], Batch [200/469]
#   Loss: 0.1652, Train Acc: 95.20%
# Epoch [2/5], Batch [300/469]
#   Loss: 0.1592, Train Acc: 95.37%
# Epoch [2/5], Batch [400/469]
#   Loss: 0.1562, Train Acc: 95.40%
#
# Epoch [2/5] 훈련 완료:
#   평균 Loss: 0.1532
#   훈련 정확도: 95.49%
#   테스트 정확도: 96.00%
# ------------------------------------------------------------
# Epoch [3/5], Batch [100/469]
#   Loss: 0.1105, Train Acc: 96.74%
# Epoch [3/5], Batch [200/469]
#   Loss: 0.1109, Train Acc: 96.70%
# Epoch [3/5], Batch [300/469]
#   Loss: 0.1117, Train Acc: 96.61%
# Epoch [3/5], Batch [400/469]
#   Loss: 0.1106, Train Acc: 96.65%
#
# Epoch [3/5] 훈련 완료:
#   평균 Loss: 0.1085
#   훈련 정확도: 96.72%
#   테스트 정확도: 96.93%
# ------------------------------------------------------------
# Epoch [4/5], Batch [100/469]
#   Loss: 0.0856, Train Acc: 97.48%
# Epoch [4/5], Batch [200/469]
#   Loss: 0.0861, Train Acc: 97.45%
# Epoch [4/5], Batch [300/469]
#   Loss: 0.0853, Train Acc: 97.54%
# Epoch [4/5], Batch [400/469]
#   Loss: 0.0842, Train Acc: 97.53%
#
# Epoch [4/5] 훈련 완료:
#   평균 Loss: 0.0837
#   훈련 정확도: 97.54%
#   테스트 정확도: 97.05%
# ------------------------------------------------------------
# Epoch [5/5], Batch [100/469]
#   Loss: 0.0637, Train Acc: 98.20%
# Epoch [5/5], Batch [200/469]
#   Loss: 0.0660, Train Acc: 98.02%
# Epoch [5/5], Batch [300/469]
#   Loss: 0.0663, Train Acc: 98.02%
# Epoch [5/5], Batch [400/469]
#   Loss: 0.0666, Train Acc: 98.00%
#
# Epoch [5/5] 훈련 완료:
#   평균 Loss: 0.0654
#   훈련 정확도: 98.06%
#   테스트 정확도: 97.30%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 98.06%
# 최종 테스트 정확도: 97.30%

# %%
# 실험1 설정 (학습률 변경 1e-3 -> 1e-1)


# 모델 초기화 (이전에 생성한 model 재사용하지 않고 새로 생성)
model = MLP().to(device)  # 모델을 GPU로 이동 (있다면)

# 손실함수: 다중 클래스 분류를 위한 CrossEntropyLoss
criterion = nn.CrossEntropyLoss()

# 최적화기: Adam (적응적 학습률 알고리즘)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)


# 하이퍼파라미터 설정
batch_size = 128        # 배치 크기
test_batch_size = 1000  # 테스트 배치 크기 (메모리 효율을 위해 크게 설정)
learning_rate = 1e-1    # 학습률
nb_epochs = 5           # 에포크 수

print("=== 훈련 설정 ===")
print(f"모델: {model.__class__.__name__}")
print(f"손실함수: {criterion.__class__.__name__}")
print(f"최적화기: {optimizer.__class__.__name__}")
print(f"디바이스: {device}")
print(f"모델 파라미터 수: {sum(p.numel() for p in model.parameters()):,}개")

# 훈련 설정 요약
print(f"\n=== 훈련 정보 ===")
print(f"전체 에포크: {nb_epochs}")
print(f"배치 크기: {batch_size}")
print(f"학습률: {learning_rate}")
print(f"에포크당 배치 수: {len(train_loader)}")
print(f"에포크당 훈련 샘플 수: {len(train_loader) * batch_size:,}")
print(f"전체 훈련 스텝: {nb_epochs * len(train_loader):,}")
# Out:
# === 훈련 설정 ===
# 모델: MLP
# 손실함수: CrossEntropyLoss
# 최적화기: Adam
# 디바이스: cuda
# 모델 파라미터 수: 79,510개
#
# === 훈련 정보 ===
# 전체 에포크: 5
# 배치 크기: 128
# 학습률: 0.1
# 에포크당 배치 수: 469
# 에포크당 훈련 샘플 수: 60,032
# 전체 훈련 스텝: 2,345

# %%
# 실험1 실행 (학습률 변경 1e-3 -> 1e-1)

# 훈련 과정 추적을 위한 리스트
train_losses = []
train_accuracies = []
test_accuracies = []

print("=== 훈련 시작 ===\n")

for epoch in range(nb_epochs):
    # 훈련 모드로 설정
    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for batch_idx, batch in enumerate(train_loader):
        # 데이터를 디바이스로 이동
        imgs = batch["image"].to(device)
        labels = batch["label"].to(device)

        # 그래디언트 초기화
        optimizer.zero_grad()

        # Forward pass
        outputs = model(imgs)
        loss = criterion(outputs, labels)

        # Backward pass
        loss.backward()

        # 파라미터 업데이트
        optimizer.step()

        # 통계 업데이트
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        # 100 배치마다 중간 결과 출력
        if (batch_idx + 1) % 100 == 0:
            current_loss = running_loss / (batch_idx + 1)
            current_acc = 100 * correct_train / total_train
            print(f"Epoch [{epoch+1}/{nb_epochs}], Batch [{batch_idx+1}/{len(train_loader)}]")
            print(f"  Loss: {current_loss:.4f}, Train Acc: {current_acc:.2f}%")

    # 에포크 종료 후 훈련 통계
    epoch_loss = running_loss / len(train_loader)
    epoch_train_acc = 100 * correct_train / total_train
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_train_acc)

    print(f"\nEpoch [{epoch+1}/{nb_epochs}] 훈련 완료:")
    print(f"  평균 Loss: {epoch_loss:.4f}")
    print(f"  훈련 정확도: {epoch_train_acc:.2f}%")

    # 테스트 정확도 계산
    model.eval()  # 평가 모드로 설정
    correct_test = 0
    total_test = 0

    with torch.no_grad():  # 그래디언트 계산 비활성화
        for batch in test_loader:
            imgs = batch["image"].to(device)
            labels = batch["label"].to(device)

            outputs = model(imgs)
            _, predicted = torch.max(outputs, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

    test_acc = 100 * correct_test / total_test
    test_accuracies.append(test_acc)
    print(f"  테스트 정확도: {test_acc:.2f}%")
    print("-" * 60)

print(f"\n=== 훈련 완료 ===")
print(f"최종 훈련 정확도: {train_accuracies[-1]:.2f}%")
print(f"최종 테스트 정확도: {test_accuracies[-1]:.2f}%")
# Out:
# === 훈련 시작 ===
#
# Epoch [1/5], Batch [100/469]
#   Loss: 4.4736, Train Acc: 37.40%
# Epoch [1/5], Batch [200/469]
#   Loss: 2.9380, Train Acc: 43.06%
# Epoch [1/5], Batch [300/469]
#   Loss: 2.4372, Train Acc: 44.09%
# Epoch [1/5], Batch [400/469]
#   Loss: 2.2089, Train Acc: 44.30%
#
# Epoch [1/5] 훈련 완료:
#   평균 Loss: 2.1182
#   훈련 정확도: 44.37%
#   테스트 정확도: 39.58%
# ------------------------------------------------------------
# Epoch [2/5], Batch [100/469]
#   Loss: 1.4751, Train Acc: 44.72%
# Epoch [2/5], Batch [200/469]
#   Loss: 1.4904, Train Acc: 45.35%
# Epoch [2/5], Batch [300/469]
#   Loss: 1.5103, Train Acc: 44.83%
# Epoch [2/5], Batch [400/469]
#   Loss: 1.4870, Train Acc: 45.48%
#
# Epoch [2/5] 훈련 완료:
#   평균 Loss: 1.5123
#   훈련 정확도: 44.70%
#   테스트 정확도: 36.33%
# ------------------------------------------------------------
# Epoch [3/5], Batch [100/469]
#   Loss: 1.8569, Train Acc: 31.59%
# Epoch [3/5], Batch [200/469]
#   Loss: 1.7897, Train Acc: 33.89%
# Epoch [3/5], Batch [300/469]
#   Loss: 1.8224, Train Acc: 32.95%
# Epoch [3/5], Batch [400/469]
#   Loss: 1.8373, Train Acc: 32.10%
#
# Epoch [3/5] 훈련 완료:
#   평균 Loss: 1.8302
#   훈련 정확도: 32.37%
#   테스트 정확도: 37.66%
# ------------------------------------------------------------
# Epoch [4/5], Batch [100/469]
#   Loss: 1.7615, Train Acc: 36.35%
# Epoch [4/5], Batch [200/469]
#   Loss: 1.8276, Train Acc: 34.18%
# Epoch [4/5], Batch [300/469]
#   Loss: 1.8526, Train Acc: 32.29%
# Epoch [4/5], Batch [400/469]
#   Loss: 1.8886, Train Acc: 32.35%
#
# Epoch [4/5] 훈련 완료:
#   평균 Loss: 1.8847
#   훈련 정확도: 31.91%
#   테스트 정확도: 35.82%
# ------------------------------------------------------------
# Epoch [5/5], Batch [100/469]
#   Loss: 1.8826, Train Acc: 29.80%
# Epoch [5/5], Batch [200/469]
#   Loss: 1.8995, Train Acc: 29.52%
# Epoch [5/5], Batch [300/469]
#   Loss: 1.9434, Train Acc: 29.62%
# Epoch [5/5], Batch [400/469]
#   Loss: 1.9352, Train Acc: 29.43%
#
# Epoch [5/5] 훈련 완료:
#   평균 Loss: 1.9321
#   훈련 정확도: 29.15%
#   테스트 정확도: 23.95%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 29.15%
# 최종 테스트 정확도: 23.95%

# %%
# 실험2 설정 (모델구조 개선 2층 신경망 -> 12층 신경망)


# 12층 신경망으로 모델구조 개선할 때 ChaGPT를 이용한 코드 생성
class MLP(nn.Module):
    def __init__(self, input_size=784, num_classes=10):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 8192), nn.ReLU(),
            nn.Linear(8192, 8192), nn.ReLU(),
            nn.Linear(8192, 4096), nn.ReLU(),
            nn.Linear(4096, 4096), nn.ReLU(),
            nn.Linear(4096, 2048), nn.ReLU(),
            nn.Linear(2048, 2048), nn.ReLU(),
            nn.Linear(2048, 1024), nn.ReLU(),
            nn.Linear(1024, 1024), nn.ReLU(),
            nn.Linear(1024, 512), nn.ReLU(),
            nn.Linear(512, 256), nn.ReLU(),
            nn.Linear(256, 128), nn.ReLU(),
            nn.Linear(128, num_classes)
          )

    def forward(self, x):
        return self.layers(x)


# 모델 초기화 (이전에 생성한 model 재사용하지 않고 새로 생성)
model = MLP().to(device)  # 모델을 GPU로 이동 (있다면)

# 손실함수: 다중 클래스 분류를 위한 CrossEntropyLoss
criterion = nn.CrossEntropyLoss()

# 최적화기: Adam (적응적 학습률 알고리즘)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# 하이퍼파라미터 설정
batch_size = 128        # 배치 크기
test_batch_size = 1000  # 테스트 배치 크기 (메모리 효율을 위해 크게 설정)
learning_rate = 1e-3    # 학습률
nb_epochs = 5           # 에포크 수

print("=== 훈련 설정 ===")
print(f"모델: {model.__class__.__name__}")
print(f"손실함수: {criterion.__class__.__name__}")
print(f"최적화기: {optimizer.__class__.__name__}")
print(f"디바이스: {device}")
print(f"모델 파라미터 수: {sum(p.numel() for p in model.parameters()):,}개")

# 훈련 설정 요약
print(f"\n=== 훈련 정보 ===")
print(f"전체 에포크: {nb_epochs}")
print(f"배치 크기: {batch_size}")
print(f"학습률: {learning_rate}")
print(f"에포크당 배치 수: {len(train_loader)}")
print(f"에포크당 훈련 샘플 수: {len(train_loader) * batch_size:,}")
print(f"전체 훈련 스텝: {nb_epochs * len(train_loader):,}")
# Out:
# === 훈련 설정 ===
# 모델: MLP
# 손실함수: CrossEntropyLoss
# 최적화기: Adam
# 디바이스: cuda
# 모델 파라미터 수: 140,312,714개
#
# === 훈련 정보 ===
# 전체 에포크: 5
# 배치 크기: 128
# 학습률: 0.001
# 에포크당 배치 수: 469
# 에포크당 훈련 샘플 수: 60,032
# 전체 훈련 스텝: 2,345

# %%
# 실험2 실행 (모델구조 개선 2층 신경망 -> 12층 신경망)

# 훈련 과정 추적을 위한 리스트
train_losses = []
train_accuracies = []
test_accuracies = []

print("=== 훈련 시작 ===\n")

for epoch in range(nb_epochs):
    # 훈련 모드로 설정
    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for batch_idx, batch in enumerate(train_loader):
        # 데이터를 디바이스로 이동
        imgs = batch["image"].to(device)
        labels = batch["label"].to(device)

        # 그래디언트 초기화
        optimizer.zero_grad()

        # Forward pass
        outputs = model(imgs)
        loss = criterion(outputs, labels)

        # Backward pass
        loss.backward()

        # 파라미터 업데이트
        optimizer.step()

        # 통계 업데이트
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        # 100 배치마다 중간 결과 출력
        if (batch_idx + 1) % 100 == 0:
            current_loss = running_loss / (batch_idx + 1)
            current_acc = 100 * correct_train / total_train
            print(f"Epoch [{epoch+1}/{nb_epochs}], Batch [{batch_idx+1}/{len(train_loader)}]")
            print(f"  Loss: {current_loss:.4f}, Train Acc: {current_acc:.2f}%")

    # 에포크 종료 후 훈련 통계
    epoch_loss = running_loss / len(train_loader)
    epoch_train_acc = 100 * correct_train / total_train
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_train_acc)

    print(f"\nEpoch [{epoch+1}/{nb_epochs}] 훈련 완료:")
    print(f"  평균 Loss: {epoch_loss:.4f}")
    print(f"  훈련 정확도: {epoch_train_acc:.2f}%")

    # 테스트 정확도 계산
    model.eval()  # 평가 모드로 설정
    correct_test = 0
    total_test = 0

    with torch.no_grad():  # 그래디언트 계산 비활성화
        for batch in test_loader:
            imgs = batch["image"].to(device)
            labels = batch["label"].to(device)

            outputs = model(imgs)
            _, predicted = torch.max(outputs, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

    test_acc = 100 * correct_test / total_test
    test_accuracies.append(test_acc)
    print(f"  테스트 정확도: {test_acc:.2f}%")
    print("-" * 60)

print(f"\n=== 훈련 완료 ===")
print(f"최종 훈련 정확도: {train_accuracies[-1]:.2f}%")
print(f"최종 테스트 정확도: {test_accuracies[-1]:.2f}%")
# Out:
# === 훈련 시작 ===
#
# Epoch [1/5], Batch [100/469]
#   Loss: 2.2691, Train Acc: 13.68%
# Epoch [1/5], Batch [200/469]
#   Loss: 1.9842, Train Acc: 19.27%
# Epoch [1/5], Batch [300/469]
#   Loss: 1.8178, Train Acc: 25.40%
# Epoch [1/5], Batch [400/469]
#   Loss: 1.6510, Train Acc: 33.31%
#
# Epoch [1/5] 훈련 완료:
#   평균 Loss: 1.5384
#   훈련 정확도: 38.96%
#   테스트 정확도: 80.87%
# ------------------------------------------------------------
# Epoch [2/5], Batch [100/469]
#   Loss: 0.6490, Train Acc: 79.36%
# Epoch [2/5], Batch [200/469]
#   Loss: 0.5257, Train Acc: 84.40%
# Epoch [2/5], Batch [300/469]
#   Loss: 0.4507, Train Acc: 87.16%
# Epoch [2/5], Batch [400/469]
#   Loss: 0.4032, Train Acc: 88.71%
#
# Epoch [2/5] 훈련 완료:
#   평균 Loss: 0.3809
#   훈련 정확도: 89.42%
#   테스트 정확도: 94.32%
# ------------------------------------------------------------
# Epoch [3/5], Batch [100/469]
#   Loss: 0.2163, Train Acc: 94.58%
# Epoch [3/5], Batch [200/469]
#   Loss: 0.2293, Train Acc: 94.40%
# Epoch [3/5], Batch [300/469]
#   Loss: 0.2781, Train Acc: 92.92%
# Epoch [3/5], Batch [400/469]
#   Loss: 0.2614, Train Acc: 93.41%
#
# Epoch [3/5] 훈련 완료:
#   평균 Loss: 0.2519
#   훈련 정확도: 93.70%
#   테스트 정확도: 95.23%
# ------------------------------------------------------------
# Epoch [4/5], Batch [100/469]
#   Loss: 0.1600, Train Acc: 96.32%
# Epoch [4/5], Batch [200/469]
#   Loss: 0.1505, Train Acc: 96.56%
# Epoch [4/5], Batch [300/469]
#   Loss: 0.1537, Train Acc: 96.43%
# Epoch [4/5], Batch [400/469]
#   Loss: 0.1534, Train Acc: 96.49%
#
# Epoch [4/5] 훈련 완료:
#   평균 Loss: 0.1534
#   훈련 정확도: 96.49%
#   테스트 정확도: 96.45%
# ------------------------------------------------------------
# Epoch [5/5], Batch [100/469]
#   Loss: 0.1184, Train Acc: 97.23%
# Epoch [5/5], Batch [200/469]
#   Loss: 0.1189, Train Acc: 97.20%
# Epoch [5/5], Batch [300/469]
#   Loss: 0.1305, Train Acc: 96.97%
# Epoch [5/5], Batch [400/469]
#   Loss: 0.1277, Train Acc: 97.06%
#
# Epoch [5/5] 훈련 완료:
#   평균 Loss: 0.1280
#   훈련 정확도: 97.09%
#   테스트 정확도: 96.46%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 97.09%
# 최종 테스트 정확도: 96.46%

# %%
# 실험2.1 설정 (모델구조 개선 2층 신경망 -> 12층 신경망 + 에포크 수 증가 5 -> 10, 과적합 관찰을 위함)


# 12층 신경망으로 모델구조 개선할 때 ChaGPT를 이용한 코드 생성
class MLP(nn.Module):
    def __init__(self, input_size=784, num_classes=10):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 8192), nn.ReLU(),
            nn.Linear(8192, 8192), nn.ReLU(),
            nn.Linear(8192, 4096), nn.ReLU(),
            nn.Linear(4096, 4096), nn.ReLU(),
            nn.Linear(4096, 2048), nn.ReLU(),
            nn.Linear(2048, 2048), nn.ReLU(),
            nn.Linear(2048, 1024), nn.ReLU(),
            nn.Linear(1024, 1024), nn.ReLU(),
            nn.Linear(1024, 512), nn.ReLU(),
            nn.Linear(512, 256), nn.ReLU(),
            nn.Linear(256, 128), nn.ReLU(),
            nn.Linear(128, num_classes)
          )

    def forward(self, x):
        return self.layers(x)


# 모델 초기화 (이전에 생성한 model 재사용하지 않고 새로 생성)
model = MLP().to(device)  # 모델을 GPU로 이동 (있다면)

# 손실함수: 다중 클래스 분류를 위한 CrossEntropyLoss
criterion = nn.CrossEntropyLoss()

# 최적화기: Adam (적응적 학습률 알고리즘)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# 하이퍼파라미터 설정
batch_size = 128        # 배치 크기
test_batch_size = 1000  # 테스트 배치 크기 (메모리 효율을 위해 크게 설정)
learning_rate = 1e-3    # 학습률
nb_epochs = 10           # 에포크 수

print("=== 훈련 설정 ===")
print(f"모델: {model.__class__.__name__}")
print(f"손실함수: {criterion.__class__.__name__}")
print(f"최적화기: {optimizer.__class__.__name__}")
print(f"디바이스: {device}")
print(f"모델 파라미터 수: {sum(p.numel() for p in model.parameters()):,}개")

# 훈련 설정 요약
print(f"\n=== 훈련 정보 ===")
print(f"전체 에포크: {nb_epochs}")
print(f"배치 크기: {batch_size}")
print(f"학습률: {learning_rate}")
print(f"에포크당 배치 수: {len(train_loader)}")
print(f"에포크당 훈련 샘플 수: {len(train_loader) * batch_size:,}")
print(f"전체 훈련 스텝: {nb_epochs * len(train_loader):,}")
# Out:
# === 훈련 설정 ===
# 모델: MLP
# 손실함수: CrossEntropyLoss
# 최적화기: Adam
# 디바이스: cuda
# 모델 파라미터 수: 140,312,714개
#
# === 훈련 정보 ===
# 전체 에포크: 10
# 배치 크기: 128
# 학습률: 0.001
# 에포크당 배치 수: 469
# 에포크당 훈련 샘플 수: 60,032
# 전체 훈련 스텝: 4,690

# %%
# 실험2.1 실행 (모델구조 개선 2층 신경망 -> 12층 신경망 + 에포크 수 증가 5 -> 10, 과적합 관찰을 위함)

# 훈련 과정 추적을 위한 리스트
train_losses = []
train_accuracies = []
test_accuracies = []

print("=== 훈련 시작 ===\n")

for epoch in range(nb_epochs):
    # 훈련 모드로 설정
    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for batch_idx, batch in enumerate(train_loader):
        # 데이터를 디바이스로 이동
        imgs = batch["image"].to(device)
        labels = batch["label"].to(device)

        # 그래디언트 초기화
        optimizer.zero_grad()

        # Forward pass
        outputs = model(imgs)
        loss = criterion(outputs, labels)

        # Backward pass
        loss.backward()

        # 파라미터 업데이트
        optimizer.step()

        # 통계 업데이트
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        # 100 배치마다 중간 결과 출력
        if (batch_idx + 1) % 100 == 0:
            current_loss = running_loss / (batch_idx + 1)
            current_acc = 100 * correct_train / total_train
            print(f"Epoch [{epoch+1}/{nb_epochs}], Batch [{batch_idx+1}/{len(train_loader)}]")
            print(f"  Loss: {current_loss:.4f}, Train Acc: {current_acc:.2f}%")

    # 에포크 종료 후 훈련 통계
    epoch_loss = running_loss / len(train_loader)
    epoch_train_acc = 100 * correct_train / total_train
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_train_acc)

    print(f"\nEpoch [{epoch+1}/{nb_epochs}] 훈련 완료:")
    print(f"  평균 Loss: {epoch_loss:.4f}")
    print(f"  훈련 정확도: {epoch_train_acc:.2f}%")

    # 테스트 정확도 계산
    model.eval()  # 평가 모드로 설정
    correct_test = 0
    total_test = 0

    with torch.no_grad():  # 그래디언트 계산 비활성화
        for batch in test_loader:
            imgs = batch["image"].to(device)
            labels = batch["label"].to(device)

            outputs = model(imgs)
            _, predicted = torch.max(outputs, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

    test_acc = 100 * correct_test / total_test
    test_accuracies.append(test_acc)
    print(f"  테스트 정확도: {test_acc:.2f}%")
    print("-" * 60)

print(f"\n=== 훈련 완료 ===")
print(f"최종 훈련 정확도: {train_accuracies[-1]:.2f}%")
print(f"최종 테스트 정확도: {test_accuracies[-1]:.2f}%")
# Out:
# === 훈련 시작 ===
#
# Epoch [1/10], Batch [100/469]
#   Loss: 2.2620, Train Acc: 14.03%
# Epoch [1/10], Batch [200/469]
#   Loss: 1.9145, Train Acc: 25.25%
# Epoch [1/10], Batch [300/469]
#   Loss: 1.6842, Train Acc: 34.32%
# Epoch [1/10], Batch [400/469]
#   Loss: 1.4657, Train Acc: 42.70%
#
# Epoch [1/10] 훈련 완료:
#   평균 Loss: 1.3411
#   훈련 정확도: 47.95%
#   테스트 정확도: 83.90%
# ------------------------------------------------------------
# Epoch [2/10], Batch [100/469]
#   Loss: 0.4777, Train Acc: 84.78%
# Epoch [2/10], Batch [200/469]
#   Loss: 0.3916, Train Acc: 88.19%
# Epoch [2/10], Batch [300/469]
#   Loss: 0.3453, Train Acc: 89.94%
# Epoch [2/10], Batch [400/469]
#   Loss: 0.3214, Train Acc: 90.71%
#
# Epoch [2/10] 훈련 완료:
#   평균 Loss: 0.3071
#   훈련 정확도: 91.26%
#   테스트 정확도: 95.47%
# ------------------------------------------------------------
# Epoch [3/10], Batch [100/469]
#   Loss: 0.1819, Train Acc: 95.11%
# Epoch [3/10], Batch [200/469]
#   Loss: 0.2487, Train Acc: 93.97%
# Epoch [3/10], Batch [300/469]
#   Loss: 0.2839, Train Acc: 93.14%
# Epoch [3/10], Batch [400/469]
#   Loss: 0.2979, Train Acc: 92.80%
#
# Epoch [3/10] 훈련 완료:
#   평균 Loss: 0.2898
#   훈련 정확도: 93.10%
#   테스트 정확도: 95.38%
# ------------------------------------------------------------
# Epoch [4/10], Batch [100/469]
#   Loss: 0.1705, Train Acc: 96.08%
# Epoch [4/10], Batch [200/469]
#   Loss: 0.1561, Train Acc: 96.38%
# Epoch [4/10], Batch [300/469]
#   Loss: 0.1526, Train Acc: 96.47%
# Epoch [4/10], Batch [400/469]
#   Loss: 0.1501, Train Acc: 96.54%
#
# Epoch [4/10] 훈련 완료:
#   평균 Loss: 0.1480
#   훈련 정확도: 96.57%
#   테스트 정확도: 96.35%
# ------------------------------------------------------------
# Epoch [5/10], Batch [100/469]
#   Loss: 0.1342, Train Acc: 96.79%
# Epoch [5/10], Batch [200/469]
#   Loss: 0.1240, Train Acc: 97.10%
# Epoch [5/10], Batch [300/469]
#   Loss: 0.1187, Train Acc: 97.30%
# Epoch [5/10], Batch [400/469]
#   Loss: 0.1165, Train Acc: 97.35%
#
# Epoch [5/10] 훈련 완료:
#   평균 Loss: 0.1171
#   훈련 정확도: 97.34%
#   테스트 정확도: 97.35%
# ------------------------------------------------------------
# Epoch [6/10], Batch [100/469]
#   Loss: 0.0920, Train Acc: 97.91%
# Epoch [6/10], Batch [200/469]
#   Loss: 0.1020, Train Acc: 97.66%
# Epoch [6/10], Batch [300/469]
#   Loss: 0.1014, Train Acc: 97.71%
# Epoch [6/10], Batch [400/469]
#   Loss: 0.1060, Train Acc: 97.63%
#
# Epoch [6/10] 훈련 완료:
#   평균 Loss: 0.1078
#   훈련 정확도: 97.57%
#   테스트 정확도: 96.95%
# ------------------------------------------------------------
# Epoch [7/10], Batch [100/469]
#   Loss: 0.0823, Train Acc: 98.12%
# Epoch [7/10], Batch [200/469]
#   Loss: 0.0850, Train Acc: 97.97%
# Epoch [7/10], Batch [300/469]
#   Loss: 0.0887, Train Acc: 97.91%
# Epoch [7/10], Batch [400/469]
#   Loss: 0.0915, Train Acc: 97.88%
#
# Epoch [7/10] 훈련 완료:
#   평균 Loss: 0.0943
#   훈련 정확도: 97.82%
#   테스트 정확도: 97.30%
# ------------------------------------------------------------
# Epoch [8/10], Batch [100/469]
#   Loss: 0.0857, Train Acc: 97.92%
# Epoch [8/10], Batch [200/469]
#   Loss: 0.0868, Train Acc: 98.06%
# Epoch [8/10], Batch [300/469]
#   Loss: 0.0836, Train Acc: 98.13%
# Epoch [8/10], Batch [400/469]
#   Loss: 0.0814, Train Acc: 98.12%
#
# Epoch [8/10] 훈련 완료:
#   평균 Loss: 0.0813
#   훈련 정확도: 98.15%
#   테스트 정확도: 97.84%
# ------------------------------------------------------------
# Epoch [9/10], Batch [100/469]
#   Loss: 0.0660, Train Acc: 98.41%
# Epoch [9/10], Batch [200/469]
#   Loss: 0.0682, Train Acc: 98.42%
# Epoch [9/10], Batch [300/469]
#   Loss: 0.0774, Train Acc: 98.27%
# Epoch [9/10], Batch [400/469]
#   Loss: 0.0799, Train Acc: 98.20%
#
# Epoch [9/10] 훈련 완료:
#   평균 Loss: 0.0817
#   훈련 정확도: 98.20%
#   테스트 정확도: 96.33%
# ------------------------------------------------------------
# Epoch [10/10], Batch [100/469]
#   Loss: 0.0818, Train Acc: 98.23%
# Epoch [10/10], Batch [200/469]
#   Loss: 0.0819, Train Acc: 98.24%
# Epoch [10/10], Batch [300/469]
#   Loss: 0.0748, Train Acc: 98.39%
# Epoch [10/10], Batch [400/469]
#   Loss: 0.0711, Train Acc: 98.46%
#
# Epoch [10/10] 훈련 완료:
#   평균 Loss: 0.0726
#   훈련 정확도: 98.45%
#   테스트 정확도: 97.09%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 98.45%
# 최종 테스트 정확도: 97.09%

# %%
# 실험2.2 설정 (모델구조 개선 2층 신경망 -> 12층 신경망 + 에포크 수 증가 5 -> 10 -> 20, 과적합 관찰을 위함)


# 12층 신경망으로 모델구조 개선할 때 ChaGPT를 이용한 코드 생성
class MLP(nn.Module):
    def __init__(self, input_size=784, num_classes=10):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 8192), nn.ReLU(),
            nn.Linear(8192, 8192), nn.ReLU(),
            nn.Linear(8192, 4096), nn.ReLU(),
            nn.Linear(4096, 4096), nn.ReLU(),
            nn.Linear(4096, 2048), nn.ReLU(),
            nn.Linear(2048, 2048), nn.ReLU(),
            nn.Linear(2048, 1024), nn.ReLU(),
            nn.Linear(1024, 1024), nn.ReLU(),
            nn.Linear(1024, 512), nn.ReLU(),
            nn.Linear(512, 256), nn.ReLU(),
            nn.Linear(256, 128), nn.ReLU(),
            nn.Linear(128, num_classes)
          )

    def forward(self, x):
        return self.layers(x)


# 모델 초기화 (이전에 생성한 model 재사용하지 않고 새로 생성)
model = MLP().to(device)  # 모델을 GPU로 이동 (있다면)

# 손실함수: 다중 클래스 분류를 위한 CrossEntropyLoss
criterion = nn.CrossEntropyLoss()

# 최적화기: Adam (적응적 학습률 알고리즘)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# 하이퍼파라미터 설정
batch_size = 128        # 배치 크기
test_batch_size = 1000  # 테스트 배치 크기 (메모리 효율을 위해 크게 설정)
learning_rate = 1e-3    # 학습률
nb_epochs = 20           # 에포크 수

print("=== 훈련 설정 ===")
print(f"모델: {model.__class__.__name__}")
print(f"손실함수: {criterion.__class__.__name__}")
print(f"최적화기: {optimizer.__class__.__name__}")
print(f"디바이스: {device}")
print(f"모델 파라미터 수: {sum(p.numel() for p in model.parameters()):,}개")

# 훈련 설정 요약
print(f"\n=== 훈련 정보 ===")
print(f"전체 에포크: {nb_epochs}")
print(f"배치 크기: {batch_size}")
print(f"학습률: {learning_rate}")
print(f"에포크당 배치 수: {len(train_loader)}")
print(f"에포크당 훈련 샘플 수: {len(train_loader) * batch_size:,}")
print(f"전체 훈련 스텝: {nb_epochs * len(train_loader):,}")
# Out:
# === 훈련 설정 ===
# 모델: MLP
# 손실함수: CrossEntropyLoss
# 최적화기: Adam
# 디바이스: cuda
# 모델 파라미터 수: 140,312,714개
#
# === 훈련 정보 ===
# 전체 에포크: 20
# 배치 크기: 128
# 학습률: 0.001
# 에포크당 배치 수: 469
# 에포크당 훈련 샘플 수: 60,032
# 전체 훈련 스텝: 9,380

# %%
# 실험2.2 실행 (모델구조 개선 2층 신경망 -> 12층 신경망 + 에포크 수 증가 5 -> 10 -> 20, 과적합 관찰을 위함)

# 훈련 과정 추적을 위한 리스트
train_losses = []
train_accuracies = []
test_accuracies = []

print("=== 훈련 시작 ===\n")

for epoch in range(nb_epochs):
    # 훈련 모드로 설정
    model.train()

    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for batch_idx, batch in enumerate(train_loader):
        # 데이터를 디바이스로 이동
        imgs = batch["image"].to(device)
        labels = batch["label"].to(device)

        # 그래디언트 초기화
        optimizer.zero_grad()

        # Forward pass
        outputs = model(imgs)
        loss = criterion(outputs, labels)

        # Backward pass
        loss.backward()

        # 파라미터 업데이트
        optimizer.step()

        # 통계 업데이트
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

        # 100 배치마다 중간 결과 출력
        if (batch_idx + 1) % 100 == 0:
            current_loss = running_loss / (batch_idx + 1)
            current_acc = 100 * correct_train / total_train
            print(f"Epoch [{epoch+1}/{nb_epochs}], Batch [{batch_idx+1}/{len(train_loader)}]")
            print(f"  Loss: {current_loss:.4f}, Train Acc: {current_acc:.2f}%")

    # 에포크 종료 후 훈련 통계
    epoch_loss = running_loss / len(train_loader)
    epoch_train_acc = 100 * correct_train / total_train
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_train_acc)

    print(f"\nEpoch [{epoch+1}/{nb_epochs}] 훈련 완료:")
    print(f"  평균 Loss: {epoch_loss:.4f}")
    print(f"  훈련 정확도: {epoch_train_acc:.2f}%")

    # 테스트 정확도 계산
    model.eval()  # 평가 모드로 설정
    correct_test = 0
    total_test = 0

    with torch.no_grad():  # 그래디언트 계산 비활성화
        for batch in test_loader:
            imgs = batch["image"].to(device)
            labels = batch["label"].to(device)

            outputs = model(imgs)
            _, predicted = torch.max(outputs, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

    test_acc = 100 * correct_test / total_test
    test_accuracies.append(test_acc)
    print(f"  테스트 정확도: {test_acc:.2f}%")
    print("-" * 60)

print(f"\n=== 훈련 완료 ===")
print(f"최종 훈련 정확도: {train_accuracies[-1]:.2f}%")
print(f"최종 테스트 정확도: {test_accuracies[-1]:.2f}%")
# Out:
# === 훈련 시작 ===
#
# Epoch [1/20], Batch [100/469]
#   Loss: 2.2939, Train Acc: 12.32%
# Epoch [1/20], Batch [200/469]
#   Loss: 1.9910, Train Acc: 18.27%
# Epoch [1/20], Batch [300/469]
#   Loss: 1.8305, Train Acc: 23.27%
# Epoch [1/20], Batch [400/469]
#   Loss: 1.7453, Train Acc: 26.97%
#
# Epoch [1/20] 훈련 완료:
#   평균 Loss: 1.6734
#   훈련 정확도: 30.76%
#   테스트 정확도: 66.32%
# ------------------------------------------------------------
# Epoch [2/20], Batch [100/469]
#   Loss: 0.9344, Train Acc: 63.34%
# Epoch [2/20], Batch [200/469]
#   Loss: 0.9980, Train Acc: 64.18%
# Epoch [2/20], Batch [300/469]
#   Loss: 0.8343, Train Acc: 70.15%
# Epoch [2/20], Batch [400/469]
#   Loss: 0.6983, Train Acc: 75.78%
#
# Epoch [2/20] 훈련 완료:
#   평균 Loss: 0.6290
#   훈련 정확도: 78.50%
#   테스트 정확도: 93.77%
# ------------------------------------------------------------
# Epoch [3/20], Batch [100/469]
#   Loss: 0.2199, Train Acc: 94.72%
# Epoch [3/20], Batch [200/469]
#   Loss: 0.2060, Train Acc: 95.07%
# Epoch [3/20], Batch [300/469]
#   Loss: 0.1962, Train Acc: 95.23%
# Epoch [3/20], Batch [400/469]
#   Loss: 0.1927, Train Acc: 95.28%
#
# Epoch [3/20] 훈련 완료:
#   평균 Loss: 0.1893
#   훈련 정확도: 95.38%
#   테스트 정확도: 96.39%
# ------------------------------------------------------------
# Epoch [4/20], Batch [100/469]
#   Loss: 0.1406, Train Acc: 96.64%
# Epoch [4/20], Batch [200/469]
#   Loss: 0.1407, Train Acc: 96.70%
# Epoch [4/20], Batch [300/469]
#   Loss: 0.1387, Train Acc: 96.71%
# Epoch [4/20], Batch [400/469]
#   Loss: 0.1375, Train Acc: 96.75%
#
# Epoch [4/20] 훈련 완료:
#   평균 Loss: 0.1381
#   훈련 정확도: 96.73%
#   테스트 정확도: 96.92%
# ------------------------------------------------------------
# Epoch [5/20], Batch [100/469]
#   Loss: 0.0980, Train Acc: 97.66%
# Epoch [5/20], Batch [200/469]
#   Loss: 0.1028, Train Acc: 97.54%
# Epoch [5/20], Batch [300/469]
#   Loss: 0.1102, Train Acc: 97.46%
# Epoch [5/20], Batch [400/469]
#   Loss: 0.1102, Train Acc: 97.49%
#
# Epoch [5/20] 훈련 완료:
#   평균 Loss: 0.1117
#   훈련 정확도: 97.44%
#   테스트 정확도: 96.75%
# ------------------------------------------------------------
# Epoch [6/20], Batch [100/469]
#   Loss: 0.1016, Train Acc: 97.62%
# Epoch [6/20], Batch [200/469]
#   Loss: 0.0918, Train Acc: 97.85%
# Epoch [6/20], Batch [300/469]
#   Loss: 0.0925, Train Acc: 97.81%
# Epoch [6/20], Batch [400/469]
#   Loss: 0.0929, Train Acc: 97.82%
#
# Epoch [6/20] 훈련 완료:
#   평균 Loss: 0.0963
#   훈련 정확도: 97.77%
#   테스트 정확도: 96.93%
# ------------------------------------------------------------
# Epoch [7/20], Batch [100/469]
#   Loss: 0.1281, Train Acc: 97.34%
# Epoch [7/20], Batch [200/469]
#   Loss: 0.1559, Train Acc: 96.41%
# Epoch [7/20], Batch [300/469]
#   Loss: 0.1510, Train Acc: 96.60%
# Epoch [7/20], Batch [400/469]
#   Loss: 0.1456, Train Acc: 96.65%
#
# Epoch [7/20] 훈련 완료:
#   평균 Loss: 0.1398
#   훈련 정확도: 96.78%
#   테스트 정확도: 97.34%
# ------------------------------------------------------------
# Epoch [8/20], Batch [100/469]
#   Loss: 0.0684, Train Acc: 98.32%
# Epoch [8/20], Batch [200/469]
#   Loss: 0.0797, Train Acc: 98.14%
# Epoch [8/20], Batch [300/469]
#   Loss: 0.0801, Train Acc: 98.12%
# Epoch [8/20], Batch [400/469]
#   Loss: 0.0840, Train Acc: 97.99%
#
# Epoch [8/20] 훈련 완료:
#   평균 Loss: 0.0905
#   훈련 정확도: 97.91%
#   테스트 정확도: 97.43%
# ------------------------------------------------------------
# Epoch [9/20], Batch [100/469]
#   Loss: 0.0887, Train Acc: 97.89%
# Epoch [9/20], Batch [200/469]
#   Loss: 0.0854, Train Acc: 98.03%
# Epoch [9/20], Batch [300/469]
#   Loss: 0.0824, Train Acc: 98.09%
# Epoch [9/20], Batch [400/469]
#   Loss: 0.0789, Train Acc: 98.23%
#
# Epoch [9/20] 훈련 완료:
#   평균 Loss: 0.0811
#   훈련 정확도: 98.20%
#   테스트 정확도: 97.39%
# ------------------------------------------------------------
# Epoch [10/20], Batch [100/469]
#   Loss: 0.0641, Train Acc: 98.48%
# Epoch [10/20], Batch [200/469]
#   Loss: 0.0597, Train Acc: 98.63%
# Epoch [10/20], Batch [300/469]
#   Loss: 0.0646, Train Acc: 98.57%
# Epoch [10/20], Batch [400/469]
#   Loss: 0.0669, Train Acc: 98.48%
#
# Epoch [10/20] 훈련 완료:
#   평균 Loss: 0.0657
#   훈련 정확도: 98.49%
#   테스트 정확도: 97.45%
# ------------------------------------------------------------
# Epoch [11/20], Batch [100/469]
#   Loss: 0.0516, Train Acc: 98.83%
# Epoch [11/20], Batch [200/469]
#   Loss: 0.0547, Train Acc: 98.83%
# Epoch [11/20], Batch [300/469]
#   Loss: 0.0603, Train Acc: 98.70%
# Epoch [11/20], Batch [400/469]
#   Loss: 0.0606, Train Acc: 98.66%
#
# Epoch [11/20] 훈련 완료:
#   평균 Loss: 0.0652
#   훈련 정확도: 98.57%
#   테스트 정확도: 97.53%
# ------------------------------------------------------------
# Epoch [12/20], Batch [100/469]
#   Loss: 0.0546, Train Acc: 98.84%
# Epoch [12/20], Batch [200/469]
#   Loss: 0.0533, Train Acc: 98.91%
# Epoch [12/20], Batch [300/469]
#   Loss: 0.0540, Train Acc: 98.81%
# Epoch [12/20], Batch [400/469]
#   Loss: 0.0592, Train Acc: 98.75%
#
# Epoch [12/20] 훈련 완료:
#   평균 Loss: 0.0592
#   훈련 정확도: 98.72%
#   테스트 정확도: 97.86%
# ------------------------------------------------------------
# Epoch [13/20], Batch [100/469]
#   Loss: 0.0520, Train Acc: 98.95%
# Epoch [13/20], Batch [200/469]
#   Loss: 0.0522, Train Acc: 98.88%
# Epoch [13/20], Batch [300/469]
#   Loss: 0.0526, Train Acc: 98.85%
# Epoch [13/20], Batch [400/469]
#   Loss: 0.0496, Train Acc: 98.91%
#
# Epoch [13/20] 훈련 완료:
#   평균 Loss: 0.0506
#   훈련 정확도: 98.87%
#   테스트 정확도: 97.52%
# ------------------------------------------------------------
# Epoch [14/20], Batch [100/469]
#   Loss: 0.0527, Train Acc: 98.91%
# Epoch [14/20], Batch [200/469]
#   Loss: 0.0496, Train Acc: 98.94%
# Epoch [14/20], Batch [300/469]
#   Loss: 0.0508, Train Acc: 98.89%
# Epoch [14/20], Batch [400/469]
#   Loss: 0.0512, Train Acc: 98.84%
#
# Epoch [14/20] 훈련 완료:
#   평균 Loss: 0.0514
#   훈련 정확도: 98.82%
#   테스트 정확도: 97.95%
# ------------------------------------------------------------
# Epoch [15/20], Batch [100/469]
#   Loss: 0.0321, Train Acc: 99.17%
# Epoch [15/20], Batch [200/469]
#   Loss: 0.0363, Train Acc: 99.09%
# Epoch [15/20], Batch [300/469]
#   Loss: 0.0441, Train Acc: 98.92%
# Epoch [15/20], Batch [400/469]
#   Loss: 0.0454, Train Acc: 98.90%
#
# Epoch [15/20] 훈련 완료:
#   평균 Loss: 0.0449
#   훈련 정확도: 98.91%
#   테스트 정확도: 98.08%
# ------------------------------------------------------------
# Epoch [16/20], Batch [100/469]
#   Loss: 0.0504, Train Acc: 98.87%
# Epoch [16/20], Batch [200/469]
#   Loss: 0.0554, Train Acc: 98.81%
# Epoch [16/20], Batch [300/469]
#   Loss: 0.0534, Train Acc: 98.88%
# Epoch [16/20], Batch [400/469]
#   Loss: 0.0555, Train Acc: 98.81%
#
# Epoch [16/20] 훈련 완료:
#   평균 Loss: 0.0543
#   훈련 정확도: 98.84%
#   테스트 정확도: 97.65%
# ------------------------------------------------------------
# Epoch [17/20], Batch [100/469]
#   Loss: 0.0606, Train Acc: 98.57%
# Epoch [17/20], Batch [200/469]
#   Loss: 0.0618, Train Acc: 98.64%
# Epoch [17/20], Batch [300/469]
#   Loss: 0.0622, Train Acc: 98.68%
# Epoch [17/20], Batch [400/469]
#   Loss: 0.0639, Train Acc: 98.65%
#
# Epoch [17/20] 훈련 완료:
#   평균 Loss: 0.0620
#   훈련 정확도: 98.66%
#   테스트 정확도: 97.46%
# ------------------------------------------------------------
# Epoch [18/20], Batch [100/469]
#   Loss: 0.0490, Train Acc: 99.09%
# Epoch [18/20], Batch [200/469]
#   Loss: 0.0461, Train Acc: 99.05%
# Epoch [18/20], Batch [300/469]
#   Loss: 0.0465, Train Acc: 99.03%
# Epoch [18/20], Batch [400/469]
#   Loss: 0.0431, Train Acc: 99.10%
#
# Epoch [18/20] 훈련 완료:
#   평균 Loss: 0.0437
#   훈련 정확도: 99.10%
#   테스트 정확도: 98.00%
# ------------------------------------------------------------
# Epoch [19/20], Batch [100/469]
#   Loss: 0.0323, Train Acc: 99.34%
# Epoch [19/20], Batch [200/469]
#   Loss: 0.0470, Train Acc: 99.09%
# Epoch [19/20], Batch [300/469]
#   Loss: 0.0577, Train Acc: 98.86%
# Epoch [19/20], Batch [400/469]
#   Loss: 0.0560, Train Acc: 98.85%
#
# Epoch [19/20] 훈련 완료:
#   평균 Loss: 0.0561
#   훈련 정확도: 98.82%
#   테스트 정확도: 97.90%
# ------------------------------------------------------------
# Epoch [20/20], Batch [100/469]
#   Loss: 0.1106, Train Acc: 98.34%
# Epoch [20/20], Batch [200/469]
#   Loss: 0.0818, Train Acc: 98.62%
# Epoch [20/20], Batch [300/469]
#   Loss: 0.0758, Train Acc: 98.66%
# Epoch [20/20], Batch [400/469]
#   Loss: 0.0694, Train Acc: 98.73%
#
# Epoch [20/20] 훈련 완료:
#   평균 Loss: 0.0652
#   훈련 정확도: 98.76%
#   테스트 정확도: 98.14%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 98.76%
# 최종 테스트 정확도: 98.14%
