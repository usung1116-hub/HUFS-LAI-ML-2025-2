# %% [markdown]
# # MNIST 손글씨 숫자 분류 튜토리얼
#
# 이 노트북에서는 PyTorch를 사용하여 MNIST 데이터셋의 손글씨 숫자를 분류하는 간단한 Multi-Layer Perceptron (MLP) 모델을 구현합니다.
#
# ## 학습 목표
# 1. PyTorch를 이용한 기본적인 신경망 구현
# 2. 데이터 로딩 및 전처리 과정 이해
# 3. 모델 훈련 및 평가 과정 체험
# 4. 예측 결과 시각화 및 분석
#
# ## 데이터셋 정보
# - **MNIST**: 28x28 픽셀의 흑백 손글씨 숫자 이미지 (0-9)
# - **훈련 데이터**: 60,000개
# - **테스트 데이터**: 10,000개

# %% [markdown]
# ## 1. 라이브러리 임포트
#
# 먼저 필요한 라이브러리들을 임포트합니다:
#
# - **torch**: PyTorch의 핵심 라이브러리
# - **torch.nn**: 신경망 레이어와 손실함수
# - **torch.optim**: 최적화 알고리즘 (Adam, SGD 등)
# - **torchvision.transforms**: 이미지 전처리
# - **datasets**: HuggingFace 데이터셋 라이브러리
# - **matplotlib**: 시각화
# - **numpy**: 수치 계산

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
from datasets import load_dataset
import matplotlib.pyplot as plt
import numpy as np

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("Using CPU")
# Out:
# PyTorch version: 2.8.0+cu126
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# ## 2. MLP (Multi-Layer Perceptron) 모델 정의
#
# 간단한 3층 신경망을 구현합니다:
#
# 1. **입력층**: 784개 뉴런 (28×28 픽셀을 1차원으로 펼침)
# 2. **은닉층**: 100개 뉴런 + ReLU 활성화 함수
# 3. **출력층**: 10개 뉴런 (0-9 클래스)
#
# ### 주요 개념:
# - **nn.Linear**: Fully Connected Layer (혹은 Dense Layer)
# - **nn.ReLU**: ReLU 활성화 함수 (음수는 0, 양수는 그대로)
# - **nn.Sequential**: 레이어들을 순차적으로 연결

# %%
class MLP(nn.Module):
    def __init__(self, input_size=784, hidden_size=100, num_classes=10):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, hidden_size),  # 784 -> 100
            nn.ReLU(),                          # 활성화 함수
            nn.Linear(hidden_size, num_classes) # 100 -> 10
        )

    def forward(self, x):
        """
        순전파 함수 // forward propagation
        x: 입력 텐서 (batch_size, 784)
        return: 출력 텐서 (batch_size, 10)
        """
        return self.layers(x)

# 모델 생성 및 구조 확인
model = MLP()
print("모델 구조:")
print(model)

# 파라미터 개수 계산
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\n총 파라미터 수: {total_params:,}")
print(f"학습 가능한 파라미터 수: {trainable_params:,}")

# 각 레이어별 파라미터 수 확인
print("\n레이어별 파라미터:")
for name, param in model.named_parameters():
    print(f"{name}: {param.shape} ({param.numel():,} 개)")
# Out:
# 모델 구조:
# MLP(
#   (layers): Sequential(
#     (0): Linear(in_features=784, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
#
# 총 파라미터 수: 79,510
# 학습 가능한 파라미터 수: 79,510
#
# 레이어별 파라미터:
# layers.0.weight: torch.Size([100, 784]) (78,400 개)
# layers.0.bias: torch.Size([100]) (100 개)
# layers.2.weight: torch.Size([10, 100]) (1,000 개)
# layers.2.bias: torch.Size([10]) (10 개)

# %% [markdown]
# ## 3. 데이터 로딩 및 전처리
#
# ### 3.1 하이퍼파라미터 설정
#
# 먼저 학습에 사용할 하이퍼파라미터들을 정의합니다:
#
# - **batch_size**: 한 번에 처리할 데이터의 개수
# - **learning_rate**: 학습률 (너무 크면 발산, 너무 작으면 학습이 느림)
# - **epochs**: 전체 데이터셋을 몇 번 반복할지

# %%
# 하이퍼파라미터 설정
batch_size = 128        # 배치 크기
test_batch_size = 1000  # 테스트 배치 크기 (메모리 효율을 위해 크게 설정)
learning_rate = 1e-3    # 학습률 (0.001)
nb_epochs = 3           # 에포크 수

print("=== 하이퍼파라미터 ===")
print(f"배치 크기: {batch_size}")
print(f"테스트 배치 크기: {test_batch_size}")
print(f"학습률: {learning_rate}")
print(f"에포크 수: {nb_epochs}")

# 디바이스 설정 (GPU가 있으면 GPU 사용)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\n사용 디바이스: {device}")
if device.type == "cuda":
    print(f"GPU 이름: {torch.cuda.get_device_name(0)}")
    print(f"GPU 메모리: {torch.cuda.get_device_properties(0).total_memory // 1024**3} GB")
# Out:
# === 하이퍼파라미터 ===
# 배치 크기: 128
# 테스트 배치 크기: 1000
# 학습률: 0.001
# 에포크 수: 3
#
# 사용 디바이스: cuda
# GPU 이름: Tesla T4
# GPU 메모리: 14 GB

# %% [markdown]
# ### 3.2 MNIST 데이터셋 로딩
#
# HuggingFace datasets 라이브러리를 사용하여 MNIST 데이터를 로드합니다.

# %%
# MNIST 데이터셋 로딩
print("MNIST 데이터셋을 다운로드 중...")
mnist = load_dataset("mnist")

# 데이터셋 정보 출력
print("\n=== 데이터셋 정보 ===")
print(f"훈련 데이터: {len(mnist['train']):,}개")
print(f"테스트 데이터: {len(mnist['test']):,}개")
print(f"클래스 수: {len(set(mnist['train']['label']))}개 (0-9)")
print(f"이미지 크기: {mnist['train'][0]['image'].size}")

# 샘플 이미지 확인
sample_image = mnist['train'][0]['image']
sample_label = mnist['train'][0]['label']
print(f"\n첫 번째 샘플: 라벨 {sample_label}")

# 클래스별 개수 확인
from collections import Counter
label_counts = Counter(mnist['train']['label'])
print("\n클래스별 데이터 개수:")
for i in range(10):
    print(f"숫자 {i}: {label_counts[i]:,}개")
# Out:
# MNIST 데이터셋을 다운로드 중...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# mnist/train-00000-of-00001.parquet:   0%|          | 0.00/15.6M [00:00<?, ?B/s]
# mnist/test-00000-of-00001.parquet:   0%|          | 0.00/2.60M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# === 데이터셋 정보 ===
# 훈련 데이터: 60,000개
# 테스트 데이터: 10,000개
# 클래스 수: 10개 (0-9)
# 이미지 크기: (28, 28)
#
# 첫 번째 샘플: 라벨 5
#
# 클래스별 데이터 개수:
# 숫자 0: 5,923개
# 숫자 1: 6,742개
# 숫자 2: 5,958개
# 숫자 3: 6,131개
# 숫자 4: 5,842개
# 숫자 5: 5,421개
# 숫자 6: 5,918개
# 숫자 7: 6,265개
# 숫자 8: 5,851개
# 숫자 9: 5,949개

# %% [markdown]
# ### 3.3 샘플 데이터 시각화
#
# 학습하기 전에 데이터가 어떻게 생겼는지 확인해보겠습니다.

# %%
# 샘플 이미지들 시각화
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
axes = axes.flatten()

for i in range(10):
    # 각 숫자(0-9)에 대해 첫 번째 샘플 찾기
    for j, label in enumerate(mnist['train']['label']):
        if label == i:
            image = mnist['train'][j]['image']
            axes[i].imshow(image, cmap='gray')
            axes[i].set_title(f'Digit {i}')
            axes[i].axis('off')
            break

plt.tight_layout()
plt.suptitle('MNIST Dataset Samples (First image of each digit)', y=1.02)
plt.show()

# %% [markdown]
# ### 3.4 데이터 정규화 (Normalization)
#
# 신경망의 학습을 안정화하기 위해 픽셀 값을 정규화합니다:
# 1. 픽셀 값을 0-1 범위로 변환 (ToTensor())
# 2. 평균과 표준편차를 이용해 정규화 (Normalize())
#
# 정규화 공식: `(픽셀값 - 평균) / 표준편차`

# %%
# 데이터셋의 평균과 표준편차 계산 (1000개 샘플로 추정)
print("데이터셋의 통계 정보를 계산 중...")
sample_data = torch.stack([
    transforms.ToTensor()(mnist['train'][i]['image'])
    for i in range(1000)
])

mean = sample_data.mean().item()
std = sample_data.std().item()
print(f"평균(mean): {mean:.4f}")
print(f"표준편차(std): {std:.4f}")

# Transform 정의
transform = transforms.Compose([
    transforms.ToTensor(),           # PIL Image -> Tensor, 0-255 -> 0-1
    transforms.Normalize((mean,), (std,))  # 정규화
])

print("\n변환 파이프라인:")
print("1. ToTensor(): PIL Image -> PyTorch Tensor (0-255 -> 0-1)")
print(f"2. Normalize(): (픽셀값 - {mean:.4f}) / {std:.4f}")

# 변환 전후 비교
original_pixel = mnist['train'][0]['image']
transformed = transform(original_pixel)
print(f"\n변환 예시:")
print(f"원본 픽셀 범위: 0-255")
print(f"ToTensor 후: 0-1")
print(f"정규화 후 범위: 약 {transformed.min():.2f} ~ {transformed.max():.2f}")
# Out:
# 데이터셋의 통계 정보를 계산 중...
# 평균(mean): 0.1282
# 표준편차(std): 0.3051
#
# 변환 파이프라인:
# 1. ToTensor(): PIL Image -> PyTorch Tensor (0-255 -> 0-1)
# 2. Normalize(): (픽셀값 - 0.1282) / 0.3051
#
# 변환 예시:
# 원본 픽셀 범위: 0-255
# ToTensor 후: 0-1
# 정규화 후 범위: 약 -0.42 ~ 2.86

# %% [markdown]
# ### 3.5 DataLoader 생성
#
# DataLoader는 데이터를 배치 단위로 불러오고, 셔플링 등의 기능을 제공합니다.

# %%
# 데이터 변환 함수 정의
def transform_dataset(dataset):
    """데이터셋에 변환을 적용하는 함수"""
    def transform_fn(batch):
        # 이미지를 텐서로 변환하고 28x28을 784로 평탄화
        images = [transform(img).view(-1) for img in batch["image"]]
        return {
            "image": torch.stack(images),
            "label": torch.tensor(batch["label"])
        }
    return dataset.with_transform(transform_fn)

# 훈련/테스트 데이터셋에 변환 적용
print("데이터셋 변환 중...")
train_dataset = transform_dataset(mnist["train"])
test_dataset = transform_dataset(mnist["test"])

# DataLoader 생성
train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True  # 훈련 데이터는 섞기
)
test_loader = DataLoader(
    test_dataset,
    batch_size=test_batch_size,
    shuffle=False  # 테스트 데이터는 순서 유지
)

print(f"훈련 DataLoader: {len(train_loader)}개 배치")
print(f"테스트 DataLoader: {len(test_loader)}개 배치")
print(f"배치당 훈련 샘플: {batch_size}개")
print(f"배치당 테스트 샘플: {test_batch_size}개")

# 첫 번째 배치 확인
sample_batch = next(iter(train_loader))
print(f"\n첫 번째 배치 shape:")
print(f"이미지: {sample_batch['image'].shape}  # (batch_size, 784)")
print(f"라벨: {sample_batch['label'].shape}    # (batch_size,)")
# Out:
# 데이터셋 변환 중...
# 훈련 DataLoader: 469개 배치
# 테스트 DataLoader: 10개 배치
# 배치당 훈련 샘플: 128개
# 배치당 테스트 샘플: 1000개
#
# 첫 번째 배치 shape:
# 이미지: torch.Size([128, 784])  # (batch_size, 784)
# 라벨: torch.Size([128])    # (batch_size,)

# %% [markdown]
# ## 4. 모델 훈련
#
# ### 4.1 모델, 손실함수, 최적화기 설정

# %%
# 모델 초기화 (이전에 생성한 model 재사용하지 않고 새로 생성)
model = MLP().to(device)  # 모델을 GPU로 이동 (있다면)

# 손실함수: 다중 클래스 분류를 위한 CrossEntropyLoss
criterion = nn.CrossEntropyLoss()

# 최적화기: Adam (적응적 학습률 알고리즘)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

print("=== 훈련 설정 ===")
print(f"모델: {model.__class__.__name__}")
print(f"손실함수: {criterion.__class__.__name__}")
print(f"최적화기: {optimizer.__class__.__name__}")
print(f"디바이스: {device}")
print(f"모델 파라미터 수: {sum(p.numel() for p in model.parameters()):,}개")

# 훈련 설정 요약
print(f"\n=== 훈련 정보 ===")
print(f"전체 에포크: {nb_epochs}")
print(f"배치 크기: {batch_size}")
print(f"학습률: {learning_rate}")
print(f"에포크당 배치 수: {len(train_loader)}")
print(f"에포크당 훈련 샘플 수: {len(train_loader) * batch_size:,}")
print(f"전체 훈련 스텝: {nb_epochs * len(train_loader):,}")
# Out:
# === 훈련 설정 ===
# 모델: MLP
# 손실함수: CrossEntropyLoss
# 최적화기: Adam
# 디바이스: cuda
# 모델 파라미터 수: 79,510개
#
# === 훈련 정보 ===
# 전체 에포크: 3
# 배치 크기: 128
# 학습률: 0.001
# 에포크당 배치 수: 469
# 에포크당 훈련 샘플 수: 60,032
# 전체 훈련 스텝: 1,407

# %% [markdown]
# ### 4.2 훈련 루프 실행
#
# 신경망 훈련의 기본 단계:
# 1. **Forward Pass**: 입력 데이터를 모델에 통과시켜 예측값 계산
# 2. **Loss 계산**: 예측값과 실제값의 차이(오차) 계산
# 3. **Backward Pass**: 역전파를 통해 각 파라미터의 그래디언트 계산
# 4. **Parameter Update**: 최적화기를 사용해 파라미터 업데이트

# %%
# 훈련 과정 추적을 위한 리스트
train_losses = []
train_accuracies = []
test_accuracies = []

print("=== 훈련 시작 ===\n")

# 훈련 루프를 과정 추적 리스트를 반환하는 함수로 변경
def training():
  train_losses = []
  train_accuracies = []
  test_accuracies = []

  for epoch in range(nb_epochs):
      # 훈련 모드로 설정
      model.train()

      running_loss = 0.0
      correct_train = 0
      total_train = 0

      for batch_idx, batch in enumerate(train_loader):
          # 데이터를 디바이스로 이동
          imgs = batch["image"].to(device)
          labels = batch["label"].to(device)

          # 그래디언트 초기화
          optimizer.zero_grad()

          # Forward pass
          outputs = model(imgs)
          loss = criterion(outputs, labels)

          # Backward pass
          loss.backward()

          # 파라미터 업데이트
          optimizer.step()

          # 통계 업데이트
          running_loss += loss.item()
          _, predicted = torch.max(outputs.data, 1)
          total_train += labels.size(0)
          correct_train += (predicted == labels).sum().item()

          # 100 배치마다 중간 결과 출력
          if (batch_idx + 1) % 100 == 0:
              current_loss = running_loss / (batch_idx + 1)
              current_acc = 100 * correct_train / total_train
              print(f"Epoch [{epoch+1}/{nb_epochs}], Batch [{batch_idx+1}/{len(train_loader)}]")
              print(f"  Loss: {current_loss:.4f}, Train Acc: {current_acc:.2f}%")

      # 에포크 종료 후 훈련 통계
      epoch_loss = running_loss / len(train_loader)
      epoch_train_acc = 100 * correct_train / total_train
      train_losses.append(epoch_loss)
      train_accuracies.append(epoch_train_acc)

      print(f"\nEpoch [{epoch+1}/{nb_epochs}] 훈련 완료:")
      print(f"  평균 Loss: {epoch_loss:.4f}")
      print(f"  훈련 정확도: {epoch_train_acc:.2f}%")

      # 테스트 정확도 계산
      model.eval()  # 평가 모드로 설정
      correct_test = 0
      total_test = 0

      with torch.no_grad():  # 그래디언트 계산 비활성화
          for batch in test_loader:
              imgs = batch["image"].to(device)
              labels = batch["label"].to(device)

              outputs = model(imgs)
              _, predicted = torch.max(outputs, 1)
              total_test += labels.size(0)
              correct_test += (predicted == labels).sum().item()

      test_acc = 100 * correct_test / total_test
      test_accuracies.append(test_acc)
      print(f"  테스트 정확도: {test_acc:.2f}%")
      print("-" * 60)

  print(f"\n=== 훈련 완료 ===")
  print(f"최종 훈련 정확도: {train_accuracies[-1]:.2f}%")
  print(f"최종 테스트 정확도: {test_accuracies[-1]:.2f}%")

  return train_losses, train_accuracies, test_accuracies

train_losses, train_accuracies, test_accuracies = training()
# Out:
# === 훈련 시작 ===
#
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6071, Train Acc: 82.77%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4506, Train Acc: 87.01%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.3837, Train Acc: 88.90%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3390, Train Acc: 90.17%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3171
#   훈련 정확도: 90.82%
#   테스트 정확도: 94.92%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1640, Train Acc: 95.32%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1541, Train Acc: 95.60%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1495, Train Acc: 95.67%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1471, Train Acc: 95.70%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1428
#   훈련 정확도: 95.81%
#   테스트 정확도: 96.23%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1089, Train Acc: 96.80%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1038, Train Acc: 96.88%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1037, Train Acc: 96.91%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1037, Train Acc: 96.91%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1018
#   훈련 정확도: 96.97%
#   테스트 정확도: 96.69%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.97%
# 최종 테스트 정확도: 96.69%

# %% [markdown]
# ## 5. 결과 분석 및 시각화
#
# ### 5.1 훈련 과정 시각화
#
# Loss와 정확도의 변화를 그래프로 확인해보겠습니다.

# %%
# 훈련 과정 시각화
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Loss 그래프
epochs_range = range(1, nb_epochs + 1)
ax1.plot(epochs_range, train_losses, 'b-', marker='o', linewidth=2, markersize=8)
ax1.set_title('Training Loss', fontsize=14, fontweight='bold')
ax1.set_xlabel('Epoch', fontsize=12)
ax1.set_ylabel('Loss', fontsize=12)
ax1.grid(True, alpha=0.3)
ax1.set_xticks(epochs_range)

# 정확도 그래프
ax2.plot(epochs_range, train_accuracies, 'g-', marker='s', linewidth=2,
         markersize=8, label='Train Accuracy')
ax2.plot(epochs_range, test_accuracies, 'r-', marker='^', linewidth=2,
         markersize=8, label='Test Accuracy')
ax2.set_title('Accuracy Comparison', fontsize=14, fontweight='bold')
ax2.set_xlabel('Epoch', fontsize=12)
ax2.set_ylabel('Accuracy (%)', fontsize=12)
ax2.grid(True, alpha=0.3)
ax2.legend(fontsize=11)
ax2.set_xticks(epochs_range)
ax2.set_ylim(80, 100)

plt.tight_layout()
plt.show()

# 최종 결과 요약
print("=== 최종 결과 요약 ===")
print(f"최종 훈련 Loss: {train_losses[-1]:.4f}")
print(f"최종 훈련 정확도: {train_accuracies[-1]:.2f}%")
print(f"최종 테스트 정확도: {test_accuracies[-1]:.2f}%")
print(f"과적합 정도: {train_accuracies[-1] - test_accuracies[-1]:.2f}% (훈련-테스트 정확도 차이)")
# Out:
# === 최종 결과 요약 ===
# 최종 훈련 Loss: 0.1368
# 최종 훈련 정확도: 96.11%
# 최종 테스트 정확도: 95.22%
# 과적합 정도: 0.89% (훈련-테스트 정확도 차이)

# %% [markdown]
# ### 5.2 예측 결과 시각화
#
# 모델이 실제로 어떻게 예측하는지 샘플 이미지들을 확인해보겠습니다. 올바른 예측과 틀린 예측을 모두 살펴보겠습니다.

# %%
# 예측 샘플 수집
model.eval()
correct_samples = []
wrong_samples = []

with torch.no_grad():
    for batch in test_loader:
        imgs = batch["image"].to(device)
        labels = batch["label"].to(device)
        outputs = model(imgs)
        _, predicted = torch.max(outputs, 1)

        # 정확한 예측과 틀린 예측 분리
        for i in range(len(imgs)):
            if len(correct_samples) >= 7 and len(wrong_samples) >= 3:
                break

            sample = (imgs[i], labels[i], predicted[i], outputs[i])
            if labels[i] == predicted[i] and len(correct_samples) < 7:
                correct_samples.append(sample)
            elif labels[i] != predicted[i] and len(wrong_samples) < 3:
                wrong_samples.append(sample)

        if len(correct_samples) >= 7 and len(wrong_samples) >= 3:
            break

# 시각화: 7개 맞춘 것 + 3개 틀린 것
display_samples = correct_samples + wrong_samples

fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.flatten()

for i, (img, true_label, pred_label, output) in enumerate(display_samples):
    # 28x28로 reshape (정규화된 상태)
    img_display = img.cpu().view(28, 28)

    # 정규화를 역변환 (시각화를 위해)
    img_display = img_display * std + mean
    img_display = torch.clamp(img_display, 0, 1)

    axes[i].imshow(img_display, cmap='gray')

    # 색상 설정: 맞으면 초록, 틀리면 빨강
    color = 'green' if true_label == pred_label else 'red'
    axes[i].set_title(f'True: {true_label.item()}, Pred: {pred_label.item()}', color=color, fontweight='bold')
    axes[i].axis('off')

plt.tight_layout()
plt.suptitle('Prediction Results (Green: Correct, Red: Wrong)', y=1.02, fontsize=16, fontweight='bold')
plt.show()

print(f"올바른 예측: {len([s for s in display_samples if s[1] == s[2]])}개")
print(f"틀린 예측: {len([s for s in display_samples if s[1] != s[2]])}개")
# Out:
# 올바른 예측: 7개
# 틀린 예측: 3개

# %% [markdown]
# ### 5.3 모델의 확신도 분석
#
# 틀리게 예측한 경우, 모델이 각 클래스에 대해 얼마나 확신했는지 확인해보겠습니다.

# %%
# 틀린 예측에 대한 상세 분석
if wrong_samples:
    wrong_img, wrong_true, wrong_pred, wrong_output = wrong_samples[0]

    # 소프트맥스를 통해 확률로 변환
    probabilities = torch.softmax(wrong_output, dim=0).cpu()

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    # 왼쪽: 틀린 예측 이미지
    img_display = wrong_img.cpu().view(28, 28) * std + mean
    img_display = torch.clamp(img_display, 0, 1)
    ax1.imshow(img_display, cmap='gray')
    ax1.set_title(f'Wrong Prediction Case\\nTrue: {wrong_true.item()}, Pred: {wrong_pred.item()}',
                  color='red', fontsize=12, fontweight='bold')
    ax1.axis('off')

    # 오른쪽: 확률 분포
    bars = ax2.bar(range(10), probabilities, alpha=0.7, color='lightblue', edgecolor='black')

    # 실제 라벨과 예측 라벨 강조
    bars[wrong_true.item()].set_color('green')
    bars[wrong_pred.item()].set_color('red')

    ax2.set_xlabel('Digit Class', fontsize=11)
    ax2.set_ylabel('Probability', fontsize=11)
    ax2.set_title('Model Confidence by Class', fontsize=12, fontweight='bold')
    ax2.set_xticks(range(10))
    ax2.grid(axis='y', alpha=0.3)

    # 범례 추가
    from matplotlib.lines import Line2D
    legend_elements = [Line2D([0], [0], color='green', lw=4, label=f'True Label ({wrong_true.item()})'),
                       Line2D([0], [0], color='red', lw=4, label=f'Predicted ({wrong_pred.item()})')]
    ax2.legend(handles=legend_elements, loc='upper right')

    plt.tight_layout()
    plt.show()

    # 상위 3개 확률 출력
    top3_probs, top3_indices = torch.topk(probabilities, 3)
    print("\\n=== 모델의 상위 3개 예측 ===")
    for i, (prob, idx) in enumerate(zip(top3_probs, top3_indices)):
        print(f"{i+1}위: 숫자 {idx.item()} (확률: {prob.item()*100:.2f}%)")

    print(f"\\n실제 라벨 {wrong_true.item()}의 확률: {probabilities[wrong_true.item()]*100:.2f}%")

else:
    print("틀린 예측 샘플이 없습니다. 모델이 모든 테스트 샘플을 정확히 예측했습니다!")
# Out:
# \n=== 모델의 상위 3개 예측 ===
# 1위: 숫자 6 (확률: 71.21%)
# 2위: 숫자 5 (확률: 27.68%)
# 3위: 숫자 2 (확률: 0.65%)
# \n실제 라벨 5의 확률: 27.68%

# %% [markdown]
# ## 6. 과제 및 실험
#
# ### 💡 학습을 위한 실험 제안
#
# 이제 기본 모델을 이해했으니, 다음과 같은 실험들을 해보세요:
#
# #### 🔧 **Try 1: 하이퍼파라미터 튜닝**
# - 학습률을 바꿔보세요 (`learning_rate = 1e-2`, `1e-4` 등)
# - 은닉층 크기를 조정해보세요 (`hidden_size = 50`, `200` 등)
# - 에포크 수를 늘려보세요 (`nb_epochs = 5` 또는 `10`)
#
# #### 🏗️ **Try 2: 모델 구조 개선**
# - 은닉층을 더 추가해보세요 (3층, 4층 신경망)
# - 다른 활성화 함수를 시도해보세요 (`nn.Tanh()`, `nn.Sigmoid()`)
# - Dropout을 추가해서 과적합을 방지해보세요
#
# #### 📈 **Try 3: 성능 분석**
# - Confusion Matrix 그리기
# - 클래스별 정확도 분석
# - 잘못 분류된 이미지들의 패턴 찾기
#
# ### 📝 **실험 결과 기록하기**
# 각 실험 후 다음을 기록해보세요:
# - 최종 테스트 정확도
# - 훈련 시간
# - 관찰된 패턴이나 인사이트

# %%
# 실험을 위한 빈 셀
# 여기서 위에서 제안한 실험들을 진행해보세요!

# 예시: 학습률을 바꿔서 재훈련
# learning_rate = 1e-2  # 원래보다 10배 큰 학습률
# model = MLP().to(device)
# optimizer = optim.Adam(model.parameters(), lr=learning_rate)
#
# 위의 훈련 루프를 다시 실행하고 결과를 비교해보세요!

print("실험을 시작해보세요! 💪")
# Out:
# 실험을 시작해보세요! 💪

# %% [markdown]
# ### 학습률 경향성 파악하기
#
# - leaning rate가 비교적 높은 경우 (원래의 값: 0.001)
#   - learning rate = 0.01
#   - learning rate = 0.1
#   - learning rate = 1
# - learning rate가 비교적 낮은 경우
#   - learning rate = 0.0001
#   - learning rate = 0.00001 (1e-5)
#   - learning rate = 0.000001 (1e-6)

# %%
learning_rate = float(input('사용할 학습률: '))
repeat_count = 10
last_train_accuracies = []
last_test_accuracies = []
for i in range(repeat_count):
  model = MLP().to(device)
  optimizer = optim.Adam(model.parameters(), lr=learning_rate)
  train_losses, train_accuracies, test_accuracies = training()
  last_train_accuracies.append(train_accuracies[-1])
  last_test_accuracies.append(test_accuracies[-1])
overfittings = []
for i in range(len(last_train_accuracies)):
  overfittings.append(last_train_accuracies[i] - last_test_accuracies[i])
print(f"평균 훈련 정확도: {np.mean(last_train_accuracies):.2f}%, 표준편차: {np.std(last_train_accuracies):.2f}%")
print(f"평균 테스트 정확도: {np.mean(last_test_accuracies):.2f}%, 표준편차: {np.std(last_test_accuracies):.2f}%")
print(f"평균 과적합도: {np.mean(overfittings):.2f}%, 표준편차: {np.std(overfittings):.2f}%")
# Out:
# 사용할 학습률: 1e-6
# Epoch [1/3], Batch [100/469]
#   Loss: 2.3246, Train Acc: 4.69%
# Epoch [1/3], Batch [200/469]
#   Loss: 2.3171, Train Acc: 5.14%
# Epoch [1/3], Batch [300/469]
#   Loss: 2.3097, Train Acc: 5.61%
# Epoch [1/3], Batch [400/469]
#   Loss: 2.3020, Train Acc: 6.22%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 2.2966
#   훈련 정확도: 6.65%
#   테스트 정확도: 9.50%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 2.2552, Train Acc: 10.12%
# Epoch [2/3], Batch [200/469]
#   Loss: 2.2470, Train Acc: 11.15%
# Epoch [2/3], Batch [300/469]
#   Loss: 2.2390, Train Acc: 12.31%
# Epoch [2/3], Batch [400/469]
#   Loss: 2.2314, Train Acc: 13.43%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 2.2266
#   훈련 정확도: 14.17%
#   테스트 정확도: 19.38%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 2.1832, Train Acc: 21.34%
# Epoch [3/3], Batch [200/469]
#   Loss: 2.1769, Train Acc: 22.79%
# Epoch [3/3], Batch [300/469]
#   Loss: 2.1702, Train Acc: 24.17%
# Epoch [3/3], Batch [400/469]
#   Loss: 2.1624, Train Acc: 25.62%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 2.1570
#   훈련 정확도: 26.57%
#   테스트 정확도: 33.75%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 26.57%
# 최종 테스트 정확도: 33.75%
# Epoch [1/3], Batch [100/469]
#   Loss: 2.3612, Train Acc: 6.16%
# Epoch [1/3], Batch [200/469]
#   Loss: 2.3481, Train Acc: 6.68%
# Epoch [1/3], Batch [300/469]
#   Loss: 2.3390, Train Acc: 7.09%
# Epoch [1/3], Batch [400/469]
#   Loss: 2.3308, Train Acc: 7.35%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 2.3244
#   훈련 정확도: 7.69%
#   테스트 정확도: 9.91%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 2.2739, Train Acc: 10.18%
# Epoch [2/3], Batch [200/469]
#   Loss: 2.2645, Train Acc: 11.25%
# Epoch [2/3], Batch [300/469]
#   Loss: 2.2569, Train Acc: 12.09%
# Epoch [2/3], Batch [400/469]
#   Loss: 2.2486, Train Acc: 13.30%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 2.2424
#   훈련 정확도: 14.22%
#   테스트 정확도: 20.86%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 2.1938, Train Acc: 22.48%
# Epoch [3/3], Batch [200/469]
#   Loss: 2.1857, Train Acc: 23.93%
# Epoch [3/3], Batch [300/469]
#   Loss: 2.1777, Train Acc: 25.02%
# Epoch [3/3], Batch [400/469]
#   Loss: 2.1702, Train Acc: 26.38%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 2.1648
#   훈련 정확도: 27.16%
#   테스트 정확도: 34.03%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 27.16%
# 최종 테스트 정확도: 34.03%
# Epoch [1/3], Batch [100/469]
#   Loss: 2.3342, Train Acc: 9.86%
# Epoch [1/3], Batch [200/469]
#   Loss: 2.3250, Train Acc: 10.18%
# Epoch [1/3], Batch [300/469]
#   Loss: 2.3174, Train Acc: 10.60%
# Epoch [1/3], Batch [400/469]
#   Loss: 2.3094, Train Acc: 11.15%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 2.3043
#   훈련 정확도: 11.52%
#   테스트 정확도: 14.51%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 2.2596, Train Acc: 15.00%
# Epoch [2/3], Batch [200/469]
#   Loss: 2.2509, Train Acc: 16.15%
# Epoch [2/3], Batch [300/469]
#   Loss: 2.2431, Train Acc: 17.07%
# Epoch [2/3], Batch [400/469]
#   Loss: 2.2350, Train Acc: 18.16%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 2.2300
#   훈련 정확도: 18.89%
#   테스트 정확도: 24.62%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 2.1841, Train Acc: 25.87%
# Epoch [3/3], Batch [200/469]
#   Loss: 2.1773, Train Acc: 27.14%
# Epoch [3/3], Batch [300/469]
#   Loss: 2.1699, Train Acc: 28.55%
# Epoch [3/3], Batch [400/469]
#   Loss: 2.1621, Train Acc: 29.93%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 2.1566
#   훈련 정확도: 31.04%
#   테스트 정확도: 39.32%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 31.04%
# 최종 테스트 정확도: 39.32%
# Epoch [1/3], Batch [100/469]
#   Loss: 2.2882, Train Acc: 13.59%
# Epoch [1/3], Batch [200/469]
#   Loss: 2.2798, Train Acc: 14.71%
# Epoch [1/3], Batch [300/469]
#   Loss: 2.2733, Train Acc: 15.68%
# Epoch [1/3], Batch [400/469]
#   Loss: 2.2660, Train Acc: 16.85%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 2.2600
#   훈련 정확도: 17.77%
#   테스트 정확도: 24.86%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 2.2143, Train Acc: 24.79%
# Epoch [2/3], Batch [200/469]
#   Loss: 2.2069, Train Acc: 26.18%
# Epoch [2/3], Batch [300/469]
#   Loss: 2.2003, Train Acc: 27.27%
# Epoch [2/3], Batch [400/469]
#   Loss: 2.1929, Train Acc: 28.51%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 2.1876
#   훈련 정확도: 29.39%
#   테스트 정확도: 36.78%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 2.1439, Train Acc: 36.68%
# Epoch [3/3], Batch [200/469]
#   Loss: 2.1354, Train Acc: 37.79%
# Epoch [3/3], Batch [300/469]
#   Loss: 2.1276, Train Acc: 38.99%
# Epoch [3/3], Batch [400/469]
#   Loss: 2.1196, Train Acc: 40.12%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 2.1144
#   훈련 정확도: 40.85%
#   테스트 정확도: 47.23%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 40.85%
# 최종 테스트 정확도: 47.23%
# Epoch [1/3], Batch [100/469]
#   Loss: 2.2914, Train Acc: 10.84%
# Epoch [1/3], Batch [200/469]
#   Loss: 2.2853, Train Acc: 11.32%
# Epoch [1/3], Batch [300/469]
#   Loss: 2.2780, Train Acc: 12.36%
# Epoch [1/3], Batch [400/469]
#   Loss: 2.2690, Train Acc: 13.88%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 2.2637
#   훈련 정확도: 14.73%
#   테스트 정확도: 21.51%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 2.2160, Train Acc: 22.71%
# Epoch [2/3], Batch [200/469]
#   Loss: 2.2104, Train Acc: 23.60%
# Epoch [2/3], Batch [300/469]
#   Loss: 2.2020, Train Acc: 24.99%
# Epoch [2/3], Batch [400/469]
#   Loss: 2.1943, Train Acc: 26.25%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 2.1893
#   훈련 정확도: 27.10%
#   테스트 정확도: 34.24%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 2.1438, Train Acc: 34.55%
# Epoch [3/3], Batch [200/469]
#   Loss: 2.1367, Train Acc: 35.63%
# Epoch [3/3], Batch [300/469]
#   Loss: 2.1288, Train Acc: 36.64%
# Epoch [3/3], Batch [400/469]
#   Loss: 2.1200, Train Acc: 37.90%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 2.1144
#   훈련 정확도: 38.61%
#   테스트 정확도: 44.54%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 38.61%
# 최종 테스트 정확도: 44.54%
# Epoch [1/3], Batch [100/469]
#   Loss: 2.3124, Train Acc: 15.12%
# Epoch [1/3], Batch [200/469]
#   Loss: 2.3036, Train Acc: 15.72%
# Epoch [1/3], Batch [300/469]
#   Loss: 2.2945, Train Acc: 16.28%
# Epoch [1/3], Batch [400/469]
#   Loss: 2.2850, Train Acc: 16.87%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 2.2795
#   훈련 정확도: 17.22%
#   테스트 정확도: 19.45%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 2.2362, Train Acc: 20.04%
# Epoch [2/3], Batch [200/469]
#   Loss: 2.2253, Train Acc: 21.53%
# Epoch [2/3], Batch [300/469]
#   Loss: 2.2173, Train Acc: 22.44%
# Epoch [2/3], Batch [400/469]
#   Loss: 2.2094, Train Acc: 23.51%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 2.2038
#   훈련 정확도: 24.27%
#   테스트 정확도: 29.44%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 2.1559, Train Acc: 31.30%
# Epoch [3/3], Batch [200/469]
#   Loss: 2.1492, Train Acc: 32.81%
# Epoch [3/3], Batch [300/469]
#   Loss: 2.1423, Train Acc: 34.01%
# Epoch [3/3], Batch [400/469]
#   Loss: 2.1350, Train Acc: 35.39%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 2.1299
#   훈련 정확도: 36.22%
#   테스트 정확도: 42.22%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 36.22%
# 최종 테스트 정확도: 42.22%
# Epoch [1/3], Batch [100/469]
#   Loss: 2.3452, Train Acc: 7.79%
# Epoch [1/3], Batch [200/469]
#   Loss: 2.3365, Train Acc: 8.06%
# Epoch [1/3], Batch [300/469]
#   Loss: 2.3280, Train Acc: 8.38%
# Epoch [1/3], Batch [400/469]
#   Loss: 2.3194, Train Acc: 8.96%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 2.3138
#   훈련 정확도: 9.47%
#   테스트 정확도: 13.52%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 2.2699, Train Acc: 13.84%
# Epoch [2/3], Batch [200/469]
#   Loss: 2.2604, Train Acc: 15.74%
# Epoch [2/3], Batch [300/469]
#   Loss: 2.2513, Train Acc: 17.36%
# Epoch [2/3], Batch [400/469]
#   Loss: 2.2432, Train Acc: 18.83%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 2.2377
#   훈련 정확도: 19.93%
#   테스트 정확도: 27.71%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 2.1942, Train Acc: 28.44%
# Epoch [3/3], Batch [200/469]
#   Loss: 2.1853, Train Acc: 29.89%
# Epoch [3/3], Batch [300/469]
#   Loss: 2.1766, Train Acc: 31.34%
# Epoch [3/3], Batch [400/469]
#   Loss: 2.1687, Train Acc: 32.53%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 2.1635
#   훈련 정확도: 33.30%
#   테스트 정확도: 39.49%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 33.30%
# 최종 테스트 정확도: 39.49%
# Epoch [1/3], Batch [100/469]
#   Loss: 2.2783, Train Acc: 12.46%
# Epoch [1/3], Batch [200/469]
#   Loss: 2.2695, Train Acc: 13.57%
# Epoch [1/3], Batch [300/469]
#   Loss: 2.2619, Train Acc: 14.41%
# Epoch [1/3], Batch [400/469]
#   Loss: 2.2541, Train Acc: 15.40%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 2.2490
#   훈련 정확도: 16.08%
#   테스트 정확도: 21.35%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 2.2047, Train Acc: 22.44%
# Epoch [2/3], Batch [200/469]
#   Loss: 2.1963, Train Acc: 23.74%
# Epoch [2/3], Batch [300/469]
#   Loss: 2.1875, Train Acc: 25.03%
# Epoch [2/3], Batch [400/469]
#   Loss: 2.1786, Train Acc: 26.43%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 2.1733
#   훈련 정확도: 27.23%
#   테스트 정확도: 33.33%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 2.1250, Train Acc: 35.12%
# Epoch [3/3], Batch [200/469]
#   Loss: 2.1193, Train Acc: 35.36%
# Epoch [3/3], Batch [300/469]
#   Loss: 2.1107, Train Acc: 36.44%
# Epoch [3/3], Batch [400/469]
#   Loss: 2.1018, Train Acc: 37.76%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 2.0964
#   훈련 정확도: 38.49%
#   테스트 정확도: 43.66%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 38.49%
# 최종 테스트 정확도: 43.66%
# Epoch [1/3], Batch [100/469]
#   Loss: 2.2979, Train Acc: 11.30%
# Epoch [1/3], Batch [200/469]
#   Loss: 2.2889, Train Acc: 12.43%
# Epoch [1/3], Batch [300/469]
#   Loss: 2.2808, Train Acc: 13.60%
# Epoch [1/3], Batch [400/469]
#   Loss: 2.2730, Train Acc: 14.79%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 2.2671
#   훈련 정확도: 15.66%
#   테스트 정확도: 22.25%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 2.2237, Train Acc: 23.05%
# Epoch [2/3], Batch [200/469]
#   Loss: 2.2164, Train Acc: 24.24%
# Epoch [2/3], Batch [300/469]
#   Loss: 2.2080, Train Acc: 25.85%
# Epoch [2/3], Batch [400/469]
#   Loss: 2.2003, Train Acc: 27.49%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 2.1953
#   훈련 정확도: 28.39%
#   테스트 정확도: 34.87%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 2.1510, Train Acc: 36.12%
# Epoch [3/3], Batch [200/469]
#   Loss: 2.1436, Train Acc: 36.92%
# Epoch [3/3], Batch [300/469]
#   Loss: 2.1363, Train Acc: 37.97%
# Epoch [3/3], Batch [400/469]
#   Loss: 2.1288, Train Acc: 38.85%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 2.1236
#   훈련 정확도: 39.56%
#   테스트 정확도: 44.24%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 39.56%
# 최종 테스트 정확도: 44.24%
# Epoch [1/3], Batch [100/469]
#   Loss: 2.3625, Train Acc: 10.84%
# Epoch [1/3], Batch [200/469]
#   Loss: 2.3553, Train Acc: 11.00%
# Epoch [1/3], Batch [300/469]
#   Loss: 2.3471, Train Acc: 11.46%
# Epoch [1/3], Batch [400/469]
#   Loss: 2.3395, Train Acc: 11.88%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 2.3342
#   훈련 정확도: 12.18%
#   테스트 정확도: 15.17%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 2.2896, Train Acc: 14.72%
# Epoch [2/3], Batch [200/469]
#   Loss: 2.2816, Train Acc: 15.36%
# Epoch [2/3], Batch [300/469]
#   Loss: 2.2738, Train Acc: 16.13%
# Epoch [2/3], Batch [400/469]
#   Loss: 2.2658, Train Acc: 16.98%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 2.2605
#   훈련 정확도: 17.61%
#   테스트 정확도: 22.76%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 2.2148, Train Acc: 22.55%
# Epoch [3/3], Batch [200/469]
#   Loss: 2.2087, Train Acc: 23.40%
# Epoch [3/3], Batch [300/469]
#   Loss: 2.2007, Train Acc: 24.70%
# Epoch [3/3], Batch [400/469]
#   Loss: 2.1934, Train Acc: 25.95%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 2.1882
#   훈련 정확도: 26.90%
#   테스트 정확도: 34.42%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 26.90%
# 최종 테스트 정확도: 34.42%
# 평균 훈련 정확도: 33.87%, 표준편차: 5.35%
# 평균 테스트 정확도: 40.29%, 표준편차: 4.64%
# 평균 과적합도: -6.42%, 표준편차: 1.03%

# %% [markdown]
# ### 은닉층 크기에 따른 경향성
#
# - 크기가 더 작은 경우
#   - hidden size = 75
#   - hidden size = 50
#   - hidden size = 25
# - 크기가 더 큰 경우
#   - hidden size = 200
#   - hidden size = 400
#   - hidden size = 600

# %%
hs = int(input('사용할 은닉층 크기: '))
repeat_count = 10
last_train_accuracies = []
last_test_accuracies = []
for i in range(repeat_count):
  model = MLP(hidden_size=hs).to(device)
  optimizer = optim.Adam(model.parameters(), lr=1e-3)
  train_losses, train_accuracies, test_accuracies = training()
  last_train_accuracies.append(train_accuracies[-1])
  last_test_accuracies.append(test_accuracies[-1])
overfittings = []
for i in range(len(last_train_accuracies)):
  overfittings.append(last_train_accuracies[i] - last_test_accuracies[i])
print(f"평균 훈련 정확도: {np.mean(last_train_accuracies):.2f}%, 표준편차: {np.std(last_train_accuracies):.2f}%")
print(f"평균 테스트 정확도: {np.mean(last_test_accuracies):.2f}%, 표준편차: {np.std(last_test_accuracies):.2f}%")
print(f"평균 과적합도: {np.mean(overfittings):.2f}%, 표준편차: {np.std(overfittings):.2f}%")
# Out:
# 사용할 은닉층 크기: 25
# Epoch [1/3], Batch [100/469]
#   Loss: 0.8550, Train Acc: 76.55%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.6194, Train Acc: 82.68%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.5207, Train Acc: 85.36%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.4643, Train Acc: 86.89%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.4387
#   훈련 정확도: 87.61%
#   테스트 정확도: 92.20%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2552, Train Acc: 92.79%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2584, Train Acc: 92.55%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2527, Train Acc: 92.72%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2512, Train Acc: 92.75%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2492
#   훈련 정확도: 92.84%
#   테스트 정확도: 93.38%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.2169, Train Acc: 93.65%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.2135, Train Acc: 93.77%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.2097, Train Acc: 93.95%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.2111, Train Acc: 93.93%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.2106
#   훈련 정확도: 93.99%
#   테스트 정확도: 94.02%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 93.99%
# 최종 테스트 정확도: 94.02%
# Epoch [1/3], Batch [100/469]
#   Loss: 0.8804, Train Acc: 75.86%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.6275, Train Acc: 82.46%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.5204, Train Acc: 85.36%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.4596, Train Acc: 87.02%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.4326
#   훈련 정확도: 87.77%
#   테스트 정확도: 93.02%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2588, Train Acc: 92.52%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2480, Train Acc: 92.93%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2418, Train Acc: 93.10%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2369, Train Acc: 93.22%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2338
#   훈련 정확도: 93.31%
#   테스트 정확도: 94.07%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1978, Train Acc: 94.55%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1995, Train Acc: 94.31%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1971, Train Acc: 94.31%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1940, Train Acc: 94.36%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1942
#   훈련 정확도: 94.39%
#   테스트 정확도: 94.71%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 94.39%
# 최종 테스트 정확도: 94.71%
# Epoch [1/3], Batch [100/469]
#   Loss: 0.8732, Train Acc: 76.23%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.6222, Train Acc: 82.98%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.5176, Train Acc: 85.68%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.4566, Train Acc: 87.29%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.4289
#   훈련 정확도: 87.96%
#   테스트 정확도: 92.30%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2453, Train Acc: 92.91%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2414, Train Acc: 93.05%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2348, Train Acc: 93.28%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2306, Train Acc: 93.41%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2263
#   훈련 정확도: 93.54%
#   테스트 정확도: 94.09%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1957, Train Acc: 94.48%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1975, Train Acc: 94.36%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1917, Train Acc: 94.51%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1894, Train Acc: 94.52%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1889
#   훈련 정확도: 94.54%
#   테스트 정확도: 94.48%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 94.54%
# 최종 테스트 정확도: 94.48%
# Epoch [1/3], Batch [100/469]
#   Loss: 0.8497, Train Acc: 76.22%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.6186, Train Acc: 82.70%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.5235, Train Acc: 85.21%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.4645, Train Acc: 86.83%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.4373
#   훈련 정확도: 87.57%
#   테스트 정확도: 92.31%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2434, Train Acc: 92.88%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2442, Train Acc: 92.89%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2422, Train Acc: 93.04%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2400, Train Acc: 93.09%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2382
#   훈련 정확도: 93.15%
#   테스트 정확도: 93.86%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.2088, Train Acc: 93.91%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.2044, Train Acc: 93.95%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1967, Train Acc: 94.21%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1943, Train Acc: 94.31%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1953
#   훈련 정확도: 94.31%
#   테스트 정확도: 94.45%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 94.31%
# 최종 테스트 정확도: 94.45%
# Epoch [1/3], Batch [100/469]
#   Loss: 0.8647, Train Acc: 77.11%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.6198, Train Acc: 83.25%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.5224, Train Acc: 85.69%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.4620, Train Acc: 87.29%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.4334
#   훈련 정확도: 88.05%
#   테스트 정확도: 92.69%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2509, Train Acc: 92.75%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2448, Train Acc: 92.91%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2387, Train Acc: 93.11%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2342, Train Acc: 93.22%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2301
#   훈련 정확도: 93.39%
#   테스트 정확도: 94.10%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1929, Train Acc: 94.41%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1971, Train Acc: 94.38%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1907, Train Acc: 94.55%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1891, Train Acc: 94.57%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1877
#   훈련 정확도: 94.64%
#   테스트 정확도: 94.83%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 94.64%
# 최종 테스트 정확도: 94.83%
# Epoch [1/3], Batch [100/469]
#   Loss: 0.8191, Train Acc: 77.48%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.5947, Train Acc: 83.49%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4989, Train Acc: 86.03%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.4468, Train Acc: 87.45%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.4225
#   훈련 정확도: 88.06%
#   테스트 정확도: 92.60%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2480, Train Acc: 92.83%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2375, Train Acc: 93.09%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2347, Train Acc: 93.08%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2291, Train Acc: 93.31%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2254
#   훈련 정확도: 93.42%
#   테스트 정확도: 94.22%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1864, Train Acc: 94.73%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1851, Train Acc: 94.59%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1846, Train Acc: 94.66%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1832, Train Acc: 94.65%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1801
#   훈련 정확도: 94.75%
#   테스트 정확도: 94.98%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 94.75%
# 최종 테스트 정확도: 94.98%
# Epoch [1/3], Batch [100/469]
#   Loss: 0.8465, Train Acc: 77.20%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.6042, Train Acc: 83.39%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.5095, Train Acc: 85.89%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.4559, Train Acc: 87.36%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.4268
#   훈련 정확도: 88.12%
#   테스트 정확도: 92.55%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2476, Train Acc: 92.72%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2399, Train Acc: 93.00%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2353, Train Acc: 93.19%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2296, Train Acc: 93.29%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2273
#   훈련 정확도: 93.35%
#   테스트 정확도: 94.19%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1873, Train Acc: 94.44%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1901, Train Acc: 94.51%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1870, Train Acc: 94.54%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1873, Train Acc: 94.55%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1856
#   훈련 정확도: 94.58%
#   테스트 정확도: 94.90%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 94.58%
# 최종 테스트 정확도: 94.90%
# Epoch [1/3], Batch [100/469]
#   Loss: 0.8515, Train Acc: 75.96%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.6142, Train Acc: 82.56%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.5171, Train Acc: 85.21%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.4618, Train Acc: 86.79%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.4347
#   훈련 정확도: 87.59%
#   테스트 정확도: 92.22%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2613, Train Acc: 92.66%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2586, Train Acc: 92.48%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2510, Train Acc: 92.57%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2442, Train Acc: 92.77%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2408
#   훈련 정확도: 92.93%
#   테스트 정확도: 93.82%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.2002, Train Acc: 94.17%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.2025, Train Acc: 94.05%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1991, Train Acc: 94.16%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1958, Train Acc: 94.30%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1958
#   훈련 정확도: 94.33%
#   테스트 정확도: 94.16%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 94.33%
# 최종 테스트 정확도: 94.16%
# Epoch [1/3], Batch [100/469]
#   Loss: 0.8077, Train Acc: 78.07%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.5813, Train Acc: 84.20%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4883, Train Acc: 86.55%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.4404, Train Acc: 87.72%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.4162
#   훈련 정확도: 88.34%
#   테스트 정확도: 92.42%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2467, Train Acc: 93.12%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2450, Train Acc: 93.05%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2404, Train Acc: 93.18%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2357, Train Acc: 93.21%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2324
#   훈련 정확도: 93.35%
#   테스트 정확도: 94.40%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.2067, Train Acc: 93.96%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.2011, Train Acc: 94.18%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1954, Train Acc: 94.35%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1942, Train Acc: 94.33%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1922
#   훈련 정확도: 94.37%
#   테스트 정확도: 94.61%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 94.37%
# 최종 테스트 정확도: 94.61%
# Epoch [1/3], Batch [100/469]
#   Loss: 0.8219, Train Acc: 77.88%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.5935, Train Acc: 83.76%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.5037, Train Acc: 85.98%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.4511, Train Acc: 87.35%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.4249
#   훈련 정확도: 88.07%
#   테스트 정확도: 92.22%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2571, Train Acc: 92.46%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2557, Train Acc: 92.60%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2503, Train Acc: 92.82%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2455, Train Acc: 92.90%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2418
#   훈련 정확도: 93.04%
#   테스트 정확도: 93.63%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.2082, Train Acc: 93.93%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.2047, Train Acc: 94.04%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.2040, Train Acc: 94.02%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.2029, Train Acc: 94.08%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1995
#   훈련 정확도: 94.16%
#   테스트 정확도: 94.45%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 94.16%
# 최종 테스트 정확도: 94.45%
# 평균 훈련 정확도: 94.41%, 표준편차: 0.22%
# 평균 테스트 정확도: 94.56%, 표준편차: 0.30%
# 평균 과적합도: -0.15%, 표준편차: 0.16%

# %% [markdown]
# ### 다른 활성화 함수의 적용
# - Tanh
# - Sigmoid

# %%
class MLP_Tanh(nn.Module):
    def __init__(self, input_size=784, hidden_size=100, num_classes=10):
        super(MLP_Tanh, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, hidden_size),  # 784 -> 100
            nn.Tanh(),                          # 활성화 함수
            nn.Linear(hidden_size, num_classes) # 100 -> 10
        )

    def forward(self, x):
        """
        순전파 함수 // forward propagation
        x: 입력 텐서 (batch_size, 784)
        return: 출력 텐서 (batch_size, 10)
        """
        return self.layers(x)

repeat_count = 10
last_train_accuracies = []
last_test_accuracies = []
for i in range(repeat_count):
  print("="*60)
  print(i+1,"번 째 반복 중...")
  model = MLP_Tanh().to(device)
  optimizer = optim.Adam(model.parameters(), lr=1e-3)
  train_losses, train_accuracies, test_accuracies = training()
  last_train_accuracies.append(train_accuracies[-1])
  last_test_accuracies.append(test_accuracies[-1])
overfittings = []
for i in range(len(last_train_accuracies)):
  overfittings.append(last_train_accuracies[i] - last_test_accuracies[i])
print(f"평균 훈련 정확도: {np.mean(last_train_accuracies):.2f}%, 표준편차: {np.std(last_train_accuracies):.2f}%")
print(f"평균 테스트 정확도: {np.mean(last_test_accuracies):.2f}%, 표준편차: {np.std(last_test_accuracies):.2f}%")
print(f"평균 과적합도: {np.mean(overfittings):.2f}%, 표준편차: {np.std(overfittings):.2f}%")
# Out:
# ============================================================
# 1 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6443, Train Acc: 83.80%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4755, Train Acc: 87.67%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4023, Train Acc: 89.43%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3574, Train Acc: 90.47%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3362
#   훈련 정확도: 90.96%
#   테스트 정확도: 94.10%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1741, Train Acc: 94.93%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1696, Train Acc: 95.13%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1677, Train Acc: 95.20%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1624, Train Acc: 95.37%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1618
#   훈련 정확도: 95.37%
#   테스트 정확도: 95.85%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1192, Train Acc: 96.56%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1224, Train Acc: 96.45%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1206, Train Acc: 96.50%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1198, Train Acc: 96.55%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1183
#   훈련 정확도: 96.60%
#   테스트 정확도: 96.51%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.60%
# 최종 테스트 정확도: 96.51%
# ============================================================
# 2 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6433, Train Acc: 83.15%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4725, Train Acc: 87.34%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.3968, Train Acc: 89.17%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3538, Train Acc: 90.24%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3311
#   훈련 정확도: 90.84%
#   테스트 정확도: 94.51%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1769, Train Acc: 94.92%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1694, Train Acc: 95.24%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1666, Train Acc: 95.26%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1611, Train Acc: 95.43%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1585
#   훈련 정확도: 95.48%
#   테스트 정확도: 96.14%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1203, Train Acc: 96.73%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1222, Train Acc: 96.65%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1183, Train Acc: 96.67%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1163, Train Acc: 96.74%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1149
#   훈련 정확도: 96.77%
#   테스트 정확도: 96.63%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.77%
# 최종 테스트 정확도: 96.63%
# ============================================================
# 3 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6478, Train Acc: 83.63%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4782, Train Acc: 87.48%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4035, Train Acc: 89.21%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3585, Train Acc: 90.28%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3354
#   훈련 정확도: 90.85%
#   테스트 정확도: 94.64%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1747, Train Acc: 94.90%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1687, Train Acc: 95.07%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1659, Train Acc: 95.22%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1619, Train Acc: 95.38%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1593
#   훈련 정확도: 95.45%
#   테스트 정확도: 95.92%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1219, Train Acc: 96.52%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1201, Train Acc: 96.58%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1174, Train Acc: 96.65%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1190, Train Acc: 96.60%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1168
#   훈련 정확도: 96.68%
#   테스트 정확도: 96.62%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.68%
# 최종 테스트 정확도: 96.62%
# ============================================================
# 4 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6558, Train Acc: 82.56%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4816, Train Acc: 86.92%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4088, Train Acc: 88.78%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3608, Train Acc: 90.01%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3396
#   훈련 정확도: 90.56%
#   테스트 정확도: 94.33%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1777, Train Acc: 95.05%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1721, Train Acc: 94.99%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1673, Train Acc: 95.18%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1657, Train Acc: 95.20%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1630
#   훈련 정확도: 95.28%
#   테스트 정확도: 95.55%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1167, Train Acc: 96.78%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1205, Train Acc: 96.66%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1196, Train Acc: 96.64%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1191, Train Acc: 96.59%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1194
#   훈련 정확도: 96.57%
#   테스트 정확도: 96.12%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.57%
# 최종 테스트 정확도: 96.12%
# ============================================================
# 5 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6484, Train Acc: 83.64%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4803, Train Acc: 87.32%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4036, Train Acc: 89.20%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3583, Train Acc: 90.33%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3360
#   훈련 정확도: 90.87%
#   테스트 정확도: 94.60%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1786, Train Acc: 94.98%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1725, Train Acc: 94.99%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1694, Train Acc: 95.11%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1653, Train Acc: 95.22%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1614
#   훈련 정확도: 95.35%
#   테스트 정확도: 95.79%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1186, Train Acc: 96.70%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1203, Train Acc: 96.57%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1188, Train Acc: 96.59%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1200, Train Acc: 96.58%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1191
#   훈련 정확도: 96.62%
#   테스트 정확도: 96.58%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.62%
# 최종 테스트 정확도: 96.58%
# ============================================================
# 6 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6528, Train Acc: 82.88%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4808, Train Acc: 87.10%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4062, Train Acc: 88.96%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3629, Train Acc: 90.02%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3395
#   훈련 정확도: 90.61%
#   테스트 정확도: 94.22%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1856, Train Acc: 94.80%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1778, Train Acc: 94.95%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1738, Train Acc: 95.03%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1689, Train Acc: 95.17%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1650
#   훈련 정확도: 95.30%
#   테스트 정확도: 96.00%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1273, Train Acc: 96.49%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1232, Train Acc: 96.61%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1224, Train Acc: 96.61%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1205, Train Acc: 96.61%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1197
#   훈련 정확도: 96.60%
#   테스트 정확도: 96.61%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.60%
# 최종 테스트 정확도: 96.61%
# ============================================================
# 7 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6458, Train Acc: 83.34%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4774, Train Acc: 87.30%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4055, Train Acc: 89.11%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3618, Train Acc: 90.11%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3381
#   훈련 정확도: 90.72%
#   테스트 정확도: 94.52%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1780, Train Acc: 95.09%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1731, Train Acc: 95.14%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1674, Train Acc: 95.32%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1634, Train Acc: 95.39%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1602
#   훈련 정확도: 95.47%
#   테스트 정확도: 95.90%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1159, Train Acc: 96.82%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1201, Train Acc: 96.55%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1194, Train Acc: 96.54%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1178, Train Acc: 96.60%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1181
#   훈련 정확도: 96.59%
#   테스트 정확도: 96.28%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.59%
# 최종 테스트 정확도: 96.28%
# ============================================================
# 8 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6373, Train Acc: 83.94%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4763, Train Acc: 87.46%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4046, Train Acc: 89.13%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3580, Train Acc: 90.22%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3345
#   훈련 정확도: 90.85%
#   테스트 정확도: 94.55%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1774, Train Acc: 94.95%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1690, Train Acc: 95.24%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1660, Train Acc: 95.24%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1622, Train Acc: 95.35%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1602
#   훈련 정확도: 95.43%
#   테스트 정확도: 96.01%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1203, Train Acc: 96.50%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1186, Train Acc: 96.56%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1164, Train Acc: 96.64%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1173, Train Acc: 96.65%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1171
#   훈련 정확도: 96.65%
#   테스트 정확도: 96.45%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.65%
# 최종 테스트 정확도: 96.45%
# ============================================================
# 9 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6349, Train Acc: 83.55%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4696, Train Acc: 87.46%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4027, Train Acc: 89.10%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3567, Train Acc: 90.22%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3346
#   훈련 정확도: 90.77%
#   테스트 정확도: 94.55%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1796, Train Acc: 94.90%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1718, Train Acc: 95.05%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1672, Train Acc: 95.18%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1615, Train Acc: 95.34%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1591
#   훈련 정확도: 95.41%
#   테스트 정확도: 95.98%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1176, Train Acc: 96.71%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1213, Train Acc: 96.56%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1182, Train Acc: 96.69%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1181, Train Acc: 96.65%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1169
#   훈련 정확도: 96.68%
#   테스트 정확도: 96.47%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.68%
# 최종 테스트 정확도: 96.47%
# ============================================================
# 10 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 0.6428, Train Acc: 83.44%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.4775, Train Acc: 87.32%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.4038, Train Acc: 89.08%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.3600, Train Acc: 90.15%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.3382
#   훈련 정확도: 90.73%
#   테스트 정확도: 94.69%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.1739, Train Acc: 95.18%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.1738, Train Acc: 95.05%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.1684, Train Acc: 95.20%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.1628, Train Acc: 95.33%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.1596
#   훈련 정확도: 95.43%
#   테스트 정확도: 96.10%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1205, Train Acc: 96.73%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1185, Train Acc: 96.71%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1182, Train Acc: 96.76%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1162, Train Acc: 96.80%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1157
#   훈련 정확도: 96.77%
#   테스트 정확도: 96.72%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 96.77%
# 최종 테스트 정확도: 96.72%
# 평균 훈련 정확도: 96.65%, 표준편차: 0.07%
# 평균 테스트 정확도: 96.50%, 표준편차: 0.17%
# 평균 과적합도: 0.15%, 표준편차: 0.13%

# %%
class MLP_Sigmoid(nn.Module):
    def __init__(self, input_size=784, hidden_size=100, num_classes=10):
        super(MLP_Sigmoid, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, hidden_size),  # 784 -> 100
            nn.Sigmoid(),                          # 활성화 함수
            nn.Linear(hidden_size, num_classes) # 100 -> 10
        )

    def forward(self, x):
        """
        순전파 함수 // forward propagation
        x: 입력 텐서 (batch_size, 784)
        return: 출력 텐서 (batch_size, 10)
        """
        return self.layers(x)

repeat_count = 10
last_train_accuracies = []
last_test_accuracies = []
for i in range(repeat_count):
  print("="*60)
  print(i+1,"번 째 반복 중...")
  model = MLP_Sigmoid().to(device)
  optimizer = optim.Adam(model.parameters(), lr=1e-3)
  train_losses, train_accuracies, test_accuracies = training()
  last_train_accuracies.append(train_accuracies[-1])
  last_test_accuracies.append(test_accuracies[-1])
overfittings = []
for i in range(len(last_train_accuracies)):
  overfittings.append(last_train_accuracies[i] - last_test_accuracies[i])
print(f"평균 훈련 정확도: {np.mean(last_train_accuracies):.2f}%, 표준편차: {np.std(last_train_accuracies):.2f}%")
print(f"평균 테스트 정확도: {np.mean(last_test_accuracies):.2f}%, 표준편차: {np.std(last_test_accuracies):.2f}%")
print(f"평균 과적합도: {np.mean(overfittings):.2f}%, 표준편차: {np.std(overfittings):.2f}%")
# Out:
# ============================================================
# 1 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 1.1090, Train Acc: 77.84%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.7927, Train Acc: 83.49%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.6477, Train Acc: 85.91%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.5628, Train Acc: 87.36%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.5210
#   훈련 정확도: 88.08%
#   테스트 정확도: 92.92%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2585, Train Acc: 92.95%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2500, Train Acc: 93.09%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2401, Train Acc: 93.33%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2338, Train Acc: 93.45%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2279
#   훈련 정확도: 93.62%
#   테스트 정확도: 94.11%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1842, Train Acc: 94.95%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1863, Train Acc: 94.89%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1829, Train Acc: 94.99%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1768, Train Acc: 95.12%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1748
#   훈련 정확도: 95.14%
#   테스트 정확도: 95.30%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 95.14%
# 최종 테스트 정확도: 95.30%
# ============================================================
# 2 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 1.1357, Train Acc: 76.95%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.8146, Train Acc: 82.99%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.6621, Train Acc: 85.71%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.5707, Train Acc: 87.30%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.5278
#   훈련 정확도: 88.03%
#   테스트 정확도: 92.88%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2463, Train Acc: 93.35%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2398, Train Acc: 93.48%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2333, Train Acc: 93.60%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2288, Train Acc: 93.66%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2261
#   훈련 정확도: 93.74%
#   테스트 정확도: 94.44%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1804, Train Acc: 94.98%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1776, Train Acc: 95.03%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1761, Train Acc: 95.08%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1733, Train Acc: 95.19%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1726
#   훈련 정확도: 95.17%
#   테스트 정확도: 95.45%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 95.17%
# 최종 테스트 정확도: 95.45%
# ============================================================
# 3 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 1.1459, Train Acc: 77.17%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.8172, Train Acc: 83.21%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.6657, Train Acc: 85.63%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.5766, Train Acc: 87.20%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.5325
#   훈련 정확도: 87.97%
#   테스트 정확도: 92.81%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2522, Train Acc: 92.95%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2489, Train Acc: 93.02%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2419, Train Acc: 93.18%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2351, Train Acc: 93.41%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2299
#   훈련 정확도: 93.55%
#   테스트 정확도: 93.96%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1800, Train Acc: 94.98%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1807, Train Acc: 94.94%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1815, Train Acc: 94.92%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1812, Train Acc: 94.96%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1780
#   훈련 정확도: 95.02%
#   테스트 정확도: 95.08%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 95.02%
# 최종 테스트 정확도: 95.08%
# ============================================================
# 4 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 1.1165, Train Acc: 77.62%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.7939, Train Acc: 83.52%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.6533, Train Acc: 85.70%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.5677, Train Acc: 87.20%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.5252
#   훈련 정확도: 87.93%
#   테스트 정확도: 92.51%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2490, Train Acc: 93.07%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2495, Train Acc: 93.05%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2438, Train Acc: 93.08%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2347, Train Acc: 93.37%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2301
#   훈련 정확도: 93.49%
#   테스트 정확도: 94.17%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1850, Train Acc: 94.86%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1827, Train Acc: 94.89%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1811, Train Acc: 94.88%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1807, Train Acc: 94.92%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1781
#   훈련 정확도: 95.03%
#   테스트 정확도: 95.07%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 95.03%
# 최종 테스트 정확도: 95.07%
# ============================================================
# 5 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 1.1102, Train Acc: 77.76%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.7924, Train Acc: 83.49%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.6457, Train Acc: 85.96%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.5618, Train Acc: 87.34%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.5208
#   훈련 정확도: 88.06%
#   테스트 정확도: 92.70%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2551, Train Acc: 92.99%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2464, Train Acc: 93.19%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2390, Train Acc: 93.39%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2338, Train Acc: 93.48%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2295
#   훈련 정확도: 93.59%
#   테스트 정확도: 94.31%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1868, Train Acc: 94.69%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1883, Train Acc: 94.71%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1834, Train Acc: 94.90%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1786, Train Acc: 95.04%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1756
#   훈련 정확도: 95.09%
#   테스트 정확도: 95.20%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 95.09%
# 최종 테스트 정확도: 95.20%
# ============================================================
# 6 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 1.1284, Train Acc: 77.15%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.8079, Train Acc: 83.07%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.6585, Train Acc: 85.65%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.5733, Train Acc: 87.12%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.5324
#   훈련 정확도: 87.79%
#   테스트 정확도: 92.53%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2570, Train Acc: 92.75%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2531, Train Acc: 92.91%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2427, Train Acc: 93.24%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2334, Train Acc: 93.50%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2308
#   훈련 정확도: 93.56%
#   테스트 정확도: 94.15%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1843, Train Acc: 94.85%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1842, Train Acc: 94.89%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1819, Train Acc: 94.97%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1791, Train Acc: 95.01%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1770
#   훈련 정확도: 95.06%
#   테스트 정확도: 95.29%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 95.06%
# 최종 테스트 정확도: 95.29%
# ============================================================
# 7 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 1.0985, Train Acc: 77.71%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.7955, Train Acc: 83.21%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.6496, Train Acc: 85.71%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.5665, Train Acc: 87.17%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.5253
#   훈련 정확도: 87.88%
#   테스트 정확도: 92.73%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2467, Train Acc: 93.20%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2460, Train Acc: 93.16%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2385, Train Acc: 93.39%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2340, Train Acc: 93.52%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2291
#   훈련 정확도: 93.63%
#   테스트 정확도: 94.40%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1907, Train Acc: 94.79%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1869, Train Acc: 94.82%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1825, Train Acc: 94.94%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1781, Train Acc: 95.10%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1757
#   훈련 정확도: 95.15%
#   테스트 정확도: 95.37%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 95.15%
# 최종 테스트 정확도: 95.37%
# ============================================================
# 8 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 1.1394, Train Acc: 77.51%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.8132, Train Acc: 83.42%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.6621, Train Acc: 85.75%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.5740, Train Acc: 87.26%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.5299
#   훈련 정확도: 88.00%
#   테스트 정확도: 92.78%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2569, Train Acc: 93.02%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2461, Train Acc: 93.21%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2415, Train Acc: 93.31%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2333, Train Acc: 93.50%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2301
#   훈련 정확도: 93.56%
#   테스트 정확도: 94.35%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1929, Train Acc: 94.72%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1888, Train Acc: 94.75%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1835, Train Acc: 94.90%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1816, Train Acc: 94.95%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1779
#   훈련 정확도: 95.04%
#   테스트 정확도: 95.16%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 95.04%
# 최종 테스트 정확도: 95.16%
# ============================================================
# 9 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 1.1469, Train Acc: 76.55%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.8152, Train Acc: 82.87%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.6645, Train Acc: 85.47%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.5747, Train Acc: 87.07%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.5312
#   훈련 정확도: 87.82%
#   테스트 정확도: 92.82%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2554, Train Acc: 92.84%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2435, Train Acc: 93.14%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2382, Train Acc: 93.27%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2335, Train Acc: 93.45%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2280
#   훈련 정확도: 93.59%
#   테스트 정확도: 94.28%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1888, Train Acc: 94.62%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1835, Train Acc: 94.82%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1817, Train Acc: 94.91%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1784, Train Acc: 94.99%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1748
#   훈련 정확도: 95.09%
#   테스트 정확도: 95.11%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 95.09%
# 최종 테스트 정확도: 95.11%
# ============================================================
# 10 번 째 반복 중...
# Epoch [1/3], Batch [100/469]
#   Loss: 1.1312, Train Acc: 76.19%
# Epoch [1/3], Batch [200/469]
#   Loss: 0.8020, Train Acc: 82.75%
# Epoch [1/3], Batch [300/469]
#   Loss: 0.6557, Train Acc: 85.36%
# Epoch [1/3], Batch [400/469]
#   Loss: 0.5674, Train Acc: 86.97%
#
# Epoch [1/3] 훈련 완료:
#   평균 Loss: 0.5249
#   훈련 정확도: 87.74%
#   테스트 정확도: 92.74%
# ------------------------------------------------------------
# Epoch [2/3], Batch [100/469]
#   Loss: 0.2571, Train Acc: 92.74%
# Epoch [2/3], Batch [200/469]
#   Loss: 0.2445, Train Acc: 93.13%
# Epoch [2/3], Batch [300/469]
#   Loss: 0.2390, Train Acc: 93.23%
# Epoch [2/3], Batch [400/469]
#   Loss: 0.2322, Train Acc: 93.38%
#
# Epoch [2/3] 훈련 완료:
#   평균 Loss: 0.2290
#   훈련 정확도: 93.47%
#   테스트 정확도: 94.17%
# ------------------------------------------------------------
# Epoch [3/3], Batch [100/469]
#   Loss: 0.1949, Train Acc: 94.47%
# Epoch [3/3], Batch [200/469]
#   Loss: 0.1888, Train Acc: 94.70%
# Epoch [3/3], Batch [300/469]
#   Loss: 0.1836, Train Acc: 94.89%
# Epoch [3/3], Batch [400/469]
#   Loss: 0.1817, Train Acc: 94.91%
#
# Epoch [3/3] 훈련 완료:
#   평균 Loss: 0.1777
#   훈련 정확도: 95.03%
#   테스트 정확도: 95.22%
# ------------------------------------------------------------
#
# === 훈련 완료 ===
# 최종 훈련 정확도: 95.03%
# 최종 테스트 정확도: 95.22%
# 평균 훈련 정확도: 95.08%, 표준편차: 0.05%
# 평균 테스트 정확도: 95.22%, 표준편차: 0.12%
# 평균 과적합도: -0.14%, 표준편차: 0.08%
